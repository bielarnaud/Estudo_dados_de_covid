# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## lendo o Dataset

# %%
df = pd.read_csv(r"C:\Users\gabri\Desktop\TCC\Data\vacinados.csv",index_col=None, header=0,sep=';',decimal=',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\gabri\Desktop\Git - Tcc\Estudo_dados_de_covid\Codes\Analises\analises_vacinas.ipynb Célula: 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gabri/Desktop/Git%20-%20Tcc/Estudo_dados_de_covid/Codes/Analises/analises_vacinas.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv(r"C:\Users\gabri\Desktop\TCC\Data\vacinados.csv",index_col=None, header=0,sep=';',decimal=',')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\gabri\Desktop\Git - Tcc\Estudo_dados_de_covid\Codes\Analises\analises_vacinas.ipynb Célula: 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gabri/Desktop/Git%20-%20Tcc/Estudo_dados_de_covid/Codes/Analises/analises_vacinas.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df
#
# NameError: name 'df' is not defined

# %%
df[["cpf","nome"]].fillna("Não informado")
# Out:
#                     cpf                           nome
# 0        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG
# 1        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG
# 2        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA
# 3        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA
# 4        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA
# ...                 ...                            ...
# 3407293  ***.619.454-**     NECIRA FERREIRA DE SANTANA
# 3407294  ***.705.064-**     SEVERINO MANOEL DE SANTANA
# 3407295  ***.705.064-**     SEVERINO MANOEL DE SANTANA
# 3407296  ***.705.064-**     SEVERINO MANOEL DE SANTANA
# 3407297   Não informado                  Não informado
#
# [3407298 rows x 2 columns]

# %%
df["dose"].value_counts()
# Out:
# 1.0    1519688
# 2.0    1312330
# 3.0     574350
# 4.0        929
# Name: dose, dtype: int64

# %%
df["grupo"].value_counts()
# Out:
# PÚBLICO EM GERAL (18 a 59 anos)                                                    1597108
# IDOSOS                                                                              782674
# TRABALHADORES DA SAÚDE                                                              302899
# PESSOAS COM COMORBIDADES                                                            181894
#  PÚBLICO EM GERAL - MENOR DE 18 ANOS                                                160520
# TRABALHADORES DA EDUCAÇÃO                                                           122576
# CRIANÇAS DE 05 A 11 ANOS                                                             60399
# PÚBLICO EM GERAL - MENOR DE 18 ANOS                                                  53459
# GESTANTES E PUÉRPERAS                                                                31957
# OUTRAS PRIORIDADES                                                                   29787
# ...

# %%
df[df["nome"] == "GABRIEL ARNAUD DE MELO FRAGOSO"]
# Out:
#                     cpf                            nome       sexo  \
# 1089668  ***.216.414-**  GABRIEL ARNAUD DE MELO FRAGOSO  MASCULINO
# 1089669  ***.216.414-**  GABRIEL ARNAUD DE MELO FRAGOSO  MASCULINO
# 1089670  ***.216.414-**  GABRIEL ARNAUD DE MELO FRAGOSO  MASCULINO
#
#                                    grupo  \
# 1089668  PÚBLICO EM GERAL (18 a 59 anos)
# 1089669  PÚBLICO EM GERAL (18 a 59 anos)
# 1089670  PÚBLICO EM GERAL (18 a 59 anos)
#
#                                                     vacina        lote  dose  \
# 1089668  2 - CHADOX1NCOV-19 - OXFORD/ASTRAZENECA (FIOCRUZ)  219VCD288Z   3.0
# 1089669                 1 - CORONAVAC - SINOVAC (BUTANTAN)      210344   1.0
# 1089670                 1 - CORONAVAC - SINOVAC (BUTANTAN)      210453   2.0
#
#         data_vacinacao               local_vacinacao
# 1089668     2022-02-21     POLICLÍNICA  ALBERT SABIN
# 1089669     2021-08-12  DRIVE THRU - CARREFOUR TORRE
# 1089670     2021-09-26           DRIVE THRU - UNICAP

# %% [markdown]
# Aparentemente ja está pré-processado

# %% [markdown]
# ## Lendo o segundo dataset

# %%
df2 = pd.read_csv(r"C:\Users\gabri\Desktop\TCC\Data\vacinados (1).csv",index_col=None, header=0,sep=';',decimal=',')
# Out:
# C:\Users\gabri\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df2
# Out:
#          faixa_etaria idade       sexo raca_cor municipio  \
# 0        40 a 44 anos    42   FEMININO    PARDA    RECIFE
# 1        40 a 44 anos    42  MASCULINO   BRANCA    RECIFE
# 2        40 a 44 anos    42  MASCULINO   BRANCA    RECIFE
# 3        40 a 44 anos    41   FEMININO    PARDA    RECIFE
# 4        45 a 49 anos    47  MASCULINO   BRANCA    RECIFE
# ...               ...   ...        ...      ...       ...
# 3422233  40 a 44 anos    40  MASCULINO   BRANCA    RECIFE
# 3422234  40 a 44 anos    40  MASCULINO   BRANCA    RECIFE
# 3422235  35 a 39 anos    36   FEMININO   BRANCA    RECIFE
# 3422236  35 a 39 anos    36   FEMININO   BRANCA    RECIFE
# 3422237  40 a 44 anos    42   FEMININO    PARDA    RECIFE
#
#                                    grupo categoria         lote  \
# 0        PÚBLICO EM GERAL (18 a 59 anos)    OUTROS       210453
# 1        PÚBLICO EM GERAL (18 a 59 anos)    OUTROS       210279
# 2        PÚBLICO EM GERAL (18 a 59 anos)    OUTROS       210215
# ...
