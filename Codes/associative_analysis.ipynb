# %%
from functions.Pre_processing_Casos_Graves import *
from functions.associative_analysis import *

# %%
# casos_graves = Pre_Processing_Casos_Graves()
# casos_graves.run(columns_symptoms,columns_to_drop,columns_dieases,path)
# df = casos_graves.df

df = pd.read_csv(r'C:\Users\gabri\Desktop\Git - Tcc\Estudo_dados_de_covid\Data\Casos Graves\df_casos_graves')
associative_analysis = associative_analysis(df)

# %%
associative_analysis.run()
# Out:
# C:\Users\gabri\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# C:\Users\gabri\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %% [markdown]
# ## Analise das associações para todos os casos graves

# %%
associative_analysis.rules1[ (associative_analysis.rules1['confidence'] >= 0.8) ].sort_values('confidence', ascending=False)
# Out:
#                                    antecedents                  consequents  \
# 16  (SYMPTOM_FEVER, SYMPTOM_AIR_INSUFFICIENCY)              (SYMPTOM_COUGH)
# 5                              (SYMPTOM_FEVER)              (SYMPTOM_COUGH)
# 20                      (SYMPTOM_COUGH, death)  (SYMPTOM_AIR_INSUFFICIENCY)
# 28                      (SYMPTOM_FEVER, death)  (SYMPTOM_AIR_INSUFFICIENCY)
# 7                   (SYMPTOM_THROAT_CONDITION)              (SYMPTOM_COUGH)
# 0                           (DISEASE_DIABETES)  (SYMPTOM_AIR_INSUFFICIENCY)
# 10                                     (death)  (SYMPTOM_AIR_INSUFFICIENCY)
# 25                      (SYMPTOM_FEVER, death)              (SYMPTOM_COUGH)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 16            0.445451            0.725731  0.388363    0.871842  1.201330
# 5             0.624647            0.725731  0.523206    0.837603  1.154151
# ...

# %% [markdown]
# ## Analise das associações apenas em caso de morte

# %%
associative_analysis.rules2[(associative_analysis.rules2['confidence'] >= 0.8) & (associative_analysis.rules2['confidence'] != 1)].sort_values('confidence', ascending=False)
# Out:
#                                            antecedents  \
# 161   (SYMPTOM_COUGH, DISEASE_DIABETES, SYMPTOM_FEVER)
# 156  (SYMPTOM_COUGH, DISEASE_DIABETES, SYMPTOM_FEVE...
# 84    (SYMPTOM_COUGH, DISEASE_DIABETES, SYMPTOM_FEVER)
# 42                   (SYMPTOM_FEVER, DISEASE_DIABETES)
# 130                  (SYMPTOM_FEVER, DISEASE_DIABETES)
# 126           (SYMPTOM_FEVER, DISEASE_DIABETES, death)
# 102                  (SYMPTOM_COUGH, DISEASE_DIABETES)
# 24                   (SYMPTOM_COUGH, DISEASE_DIABETES)
# 98            (SYMPTOM_COUGH, DISEASE_DIABETES, death)
# 144                     (SYMPTOM_COUGH, SYMPTOM_FEVER)
# 140              (SYMPTOM_COUGH, SYMPTOM_FEVER, death)
# 60                      (SYMPTOM_COUGH, SYMPTOM_FEVER)
# 10                                     (SYMPTOM_COUGH)
# 66                              (SYMPTOM_COUGH, death)
# 69                                     (SYMPTOM_COUGH)
# 2                                   (DISEASE_DIABETES)
# ...
