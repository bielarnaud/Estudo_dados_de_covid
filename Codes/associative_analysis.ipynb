# %%
from functions.Pre_Processing_Casos_Graves import *
from functions.associative_analysis import *

# %%
casos_graves = Pre_Processing_Casos_Graves()
casos_graves.run(columns_symptoms,columns_to_drop,columns_dieases,path)
df = casos_graves.df
associative_analysis = associative_analysis(df)
# Out:
# c:\Users\gabri\Desktop\Git - Tcc\Estudo_dados_de_covid\Codes\functions\Pre_Processing_Casos_Graves.py:282: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df[column][i] = 1
# c:\Users\gabri\Desktop\Git - Tcc\Estudo_dados_de_covid\Codes\functions\Pre_Processing_Casos_Graves.py:294: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df[column][i] = 1

# %%
associative_analysis.run()
# Out:
# C:\Users\gabri\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# C:\Users\gabri\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
associative_analysis.rules1[ (associative_analysis.rules1['confidence'] >= 0.8) ].sort_values('confidence', ascending=False)
# Out:
#                                    antecedents                  consequents  \
# 14  (SYMPTOM_AIR_INSUFFICIENCY, SYMPTOM_FEVER)              (SYMPTOM_COUGH)
# 5                              (SYMPTOM_FEVER)              (SYMPTOM_COUGH)
# 7                   (SYMPTOM_THROAT_CONDITION)              (SYMPTOM_COUGH)
# 0                           (DISEASE_DIABETES)  (SYMPTOM_AIR_INSUFFICIENCY)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 14            0.445451            0.725731  0.388363    0.871842  1.201330
# 5             0.624647            0.725731  0.523206    0.837603  1.154151
# 7             0.153753            0.725731  0.126197    0.820778  1.130968
# 0             0.161328            0.674324  0.129793    0.804525  1.193084
#
#     leverage  conviction
# 14  0.065085    2.140091
# 5   0.069880    1.688878
# 7   0.014614    1.530335
# 0   0.021005    1.666077

# %%
associative_analysis.rules2[(associative_analysis.rules2['confidence'] >= 0.8)].sort_values('confidence', ascending=False)
# Out:
#                                           antecedents  \
# 36   (DISEASE_DIABETES, SYMPTOM_COUGH, SYMPTOM_FEVER)
# 24                  (DISEASE_DIABETES, SYMPTOM_FEVER)
# 12                  (DISEASE_DIABETES, SYMPTOM_COUGH)
# 30                     (SYMPTOM_COUGH, SYMPTOM_FEVER)
# 6                                     (SYMPTOM_COUGH)
# 2                                  (DISEASE_DIABETES)
# 10                                    (SYMPTOM_FEVER)
# 38  (SYMPTOM_AIR_INSUFFICIENCY, DISEASE_DIABETES, ...
# 32         (SYMPTOM_AIR_INSUFFICIENCY, SYMPTOM_FEVER)
# 19                  (DISEASE_DIABETES, SYMPTOM_FEVER)
# 9                                     (SYMPTOM_FEVER)
#
#                     consequents  antecedent support  consequent support  \
# 36  (SYMPTOM_AIR_INSUFFICIENCY)            0.135702            0.803724
# 24  (SYMPTOM_AIR_INSUFFICIENCY)            0.167487            0.803724
# 12  (SYMPTOM_AIR_INSUFFICIENCY)            0.193279            0.803724
# 30  (SYMPTOM_AIR_INSUFFICIENCY)            0.460188            0.803724
# 6   (SYMPTOM_AIR_INSUFFICIENCY)            0.655073            0.803724
# 2   (SYMPTOM_AIR_INSUFFICIENCY)            0.291096            0.803724
# 10  (SYMPTOM_AIR_INSUFFICIENCY)            0.574914            0.803724
# 38              (SYMPTOM_COUGH)            0.143193            0.655073
# 32              (SYMPTOM_COUGH)            0.476670            0.655073
# 19              (SYMPTOM_COUGH)            0.167487            0.655073
# 9               (SYMPTOM_COUGH)            0.574914            0.655073
#
#      support  confidence      lift  leverage  conviction
# 36  0.117616    0.866719  1.078379  0.008549    1.472648
# 24  0.143193    0.854952  1.063738  0.008580    1.353178
# 12  0.164598    0.851606  1.059574  0.009254    1.322664
# 30  0.388271    0.843721  1.049764  0.018406    1.255931
# 6   0.546768    0.834668  1.038500  0.020270    1.187158
# 2   0.242402    0.832721  1.036077  0.008441    1.173340
# 10  0.476670    0.829114  1.031590  0.014597    1.148576
# 38  0.117616    0.821375  1.253869  0.023813    1.931015
# 32  0.388271    0.814549  1.243448  0.076017    1.859934
# 19  0.135702    0.810224  1.236845  0.025986    1.817546
# 9   0.460188    0.800447  1.221920  0.083578    1.728497
