# %%
import pandas as pd

# %% [markdown]
# ### Tabelas para as métricas:

# %%
ranking_f1_90 = pd.DataFrame(columns = ['Modelo', 'Período', 'f1 score'])
ranking_precision_90 = pd.DataFrame(columns = ['Modelo', 'Período', 'precision score'])
ranking_recall_90 = pd.DataFrame(columns = ['Modelo', 'Período', 'recall score'])
ranking_auc_roc_score_90 = pd.DataFrame(columns = ['Modelo', 'Período', 'auc roc score'])

# %%
ranking_f1_120 = pd.DataFrame(columns = ['Modelo', 'Período', 'f1 score'])
ranking_precision_120 = pd.DataFrame(columns = ['Modelo', 'Período', 'precision score'])
ranking_recall_120 = pd.DataFrame(columns = ['Modelo', 'Período', 'recall score'])
ranking_auc_roc_score_120 = pd.DataFrame(columns = ['Modelo', 'Período', 'auc roc score'])

# %% [markdown]
# # Métricas de cada modelo:

# %% [markdown]
# ## XGBoost:

# %% [markdown]
# #### 90 Dias:

# %%
metricas_90_xg = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_90_xg_final.csv")
metricas_90_xg
# Out:
#                      Períodos  accuracy score  f1 score  f1 score macro  \
# 0   26/02/2020 até 26/05/2020        0.741158  0.558230        0.687592
# 1   27/03/2020 até 25/06/2020        0.600951  0.540348        0.593891
# 2   26/04/2020 até 25/07/2020        0.565685  0.464408        0.549580
# 3   26/05/2020 até 24/08/2020        0.617550  0.437543        0.573908
# 4   25/06/2020 até 23/09/2020        0.655196  0.407101        0.582007
# 5   25/07/2020 até 23/10/2020        0.661736  0.463224        0.608142
# 6   24/08/2020 até 22/11/2020        0.656881  0.457971        0.603482
# 7   23/09/2020 até 22/12/2020        0.659004  0.542652        0.635406
# 8   23/10/2020 até 21/01/2021        0.633880  0.551839        0.621185
# 9   22/11/2020 até 20/02/2021        0.658316  0.582838        0.646752
# 10  22/12/2020 até 22/03/2021        0.650591  0.570218        0.637928
# 11  21/01/2021 até 21/04/2021        0.646420  0.547350        0.628631
# ...

# %%
metricas_90_xg_final = metricas_90_xg.drop(['accuracy score', 'f1 score macro', 'f1 score micro', 'f1 score weighted', 'precision score macro', 'precision score micro', 'precision score weighted', 'recall score macro', 'recall score micro', 'recall score weighted'], axis=1)
metricas_90_xg_final.head(5)
# Out:
#                     Períodos  f1 score  precision score  recall score  \
# 0  26/02/2020 até 26/05/2020  0.558230         0.459572      0.710826
# 1  27/03/2020 até 25/06/2020  0.540348         0.392055      0.869066
# 2  26/04/2020 até 25/07/2020  0.464408         0.315544      0.879182
# 3  26/05/2020 até 24/08/2020  0.437543         0.302193      0.792500
# 4  25/06/2020 até 23/09/2020  0.407101         0.298611      0.639405
#
#    roc_auc score
# 0       0.730524
# 1       0.685453
# 2       0.679713
# 3       0.684812
# 4       0.649094

# %% [markdown]
# ### Tabelas Ordenadas pelas métricas:

# %% [markdown]
# #### f1 score:

# %%
metricas_90_xg_final_f1 = metricas_90_xg_final.sort_values(by=['f1 score'], ascending=False)
metricas_90_xg_final_f1.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 9   22/11/2020 até 20/02/2021  0.582838         0.496382      0.705761
# 15  21/05/2021 até 19/08/2021  0.578947         0.464789      0.767442
# 10  22/12/2020 até 22/03/2021  0.570218         0.473843      0.715805
# 23  16/01/2022 até 16/04/2022  0.559140         0.508380      0.621160
# 0   26/02/2020 até 26/05/2020  0.558230         0.459572      0.710826
#
#     roc_auc score
# 9        0.669915
# 15       0.655417
# 10       0.667583
# 23       0.630621
# 0        0.730524

# %% [markdown]
# #### Precision score:

# %%
metricas_90_xg_final_precision = metricas_90_xg_final.sort_values(by=['precision score'], ascending=False)
metricas_90_xg_final_precision.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 23  16/01/2022 até 16/04/2022  0.559140         0.508380      0.621160
# 9   22/11/2020 até 20/02/2021  0.582838         0.496382      0.705761
# 7   23/09/2020 até 22/12/2020  0.542652         0.491620      0.605505
# 8   23/10/2020 até 21/01/2021  0.551839         0.477569      0.653465
# 10  22/12/2020 até 22/03/2021  0.570218         0.473843      0.715805
#
#     roc_auc score
# 23       0.630621
# 9        0.669915
# 7        0.645675
# 8        0.638516
# 10       0.667583

# %% [markdown]
# #### Recall score:

# %%
metricas_90_xg_final_recall = metricas_90_xg_final.sort_values(by=['recall score'], ascending=False)
metricas_90_xg_final_recall.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 2   26/04/2020 até 25/07/2020  0.464408         0.315544      0.879182
# 1   27/03/2020 até 25/06/2020  0.540348         0.392055      0.869066
# 3   26/05/2020 até 24/08/2020  0.437543         0.302193      0.792500
# 17  20/07/2021 até 18/10/2021  0.483660         0.348399      0.790598
# 13  22/03/2021 até 20/06/2021  0.503198         0.373418      0.771242
#
#     roc_auc score
# 2        0.679713
# 1        0.685453
# 3        0.684812
# 17       0.631177
# 13       0.624269

# %% [markdown]
# #### AUC ROC score:

# %%
metricas_90_xg_final_auc_roc_score = metricas_90_xg_final.sort_values(by=['roc_auc score'], ascending=False)
metricas_90_xg_final_auc_roc_score.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 26/05/2020  0.558230         0.459572      0.710826
# 25  17/03/2022 até 15/06/2022  0.328358         0.213592      0.709677
# 24  15/02/2022 até 16/05/2022  0.557173         0.457338      0.712766
# 1   27/03/2020 até 25/06/2020  0.540348         0.392055      0.869066
# 3   26/05/2020 até 24/08/2020  0.437543         0.302193      0.792500
#
#     roc_auc score
# 0        0.730524
# 25       0.710196
# 24       0.686511
# 1        0.685453
# 3        0.684812

# %% [markdown]
# ### Adicionando nas tabelas finais:

# %%
ranking_f1_90 = ranking_f1_90.append({'Modelo' : 'XGBoost', 'Período' : '22/11/2020 até 20/02/2021', 'f1 score' : 0.582838}, ignore_index = True)
ranking_precision_90 = ranking_precision_90.append({'Modelo' : 'XGBoost', 'Período' : '16/01/2022 até 16/04/2022', 'precision score' : 0.508380}, ignore_index = True)
ranking_recall_90 = ranking_recall_90.append({'Modelo' : 'XGBoost', 'Período' : '26/04/2020 até 25/07/2020', 'recall score' : 0.879182}, ignore_index = True)
ranking_auc_roc_score_90 = ranking_auc_roc_score_90.append({'Modelo' : 'XGBoost', 'Período' : '26/02/2020 até 26/05/2020', 'auc roc score' : 0.730524}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\3060493777.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_f1_90 = ranking_f1_90.append({'Modelo' : 'XGBoost', 'Período' : '22/11/2020 até 20/02/2021', 'f1 score' : 0.582838}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\3060493777.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_precision_90 = ranking_precision_90.append({'Modelo' : 'XGBoost', 'Período' : '16/01/2022 até 16/04/2022', 'precision score' : 0.508380}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\3060493777.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# #### 120 Dias:

# %%
metricas_120_xg = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_120_xg_final.csv")
metricas_120_xg
# Out:
#                      Períodos  accuracy score  f1 score  f1 score macro  \
# 0   26/02/2020 até 25/06/2020        0.668820  0.569406        0.650172
# 1   27/03/2020 até 25/07/2020        0.575335  0.491662        0.563509
# 2   26/04/2020 até 24/08/2020        0.589249  0.443511        0.559003
# 3   26/05/2020 até 23/09/2020        0.627799  0.454918        0.586170
# 4   25/06/2020 até 23/10/2020        0.615127  0.445516        0.575398
# 5   25/07/2020 até 22/11/2020        0.649825  0.483971        0.609484
# 6   24/08/2020 até 22/12/2020        0.634671  0.475793        0.597718
# 7   23/09/2020 até 21/01/2021        0.644527  0.556072        0.629830
# 8   23/10/2020 até 20/02/2021        0.625731  0.575392        0.620396
# 9   22/11/2020 até 22/03/2021        0.648497  0.571568        0.636786
# 10  22/12/2020 até 21/04/2021        0.635773  0.556282        0.623696
# 11  21/01/2021 até 21/05/2021        0.616645  0.550061        0.608062
# ...

# %%
metricas_120_xg_final = metricas_120_xg.drop(['accuracy score', 'f1 score macro', 'f1 score micro', 'f1 score weighted', 'precision score macro', 'precision score micro', 'precision score weighted', 'recall score macro', 'recall score micro', 'recall score weighted'], axis=1)
metricas_120_xg_final.head(5)
# Out:
#                     Períodos  f1 score  precision score  recall score  \
# 0  26/02/2020 até 25/06/2020  0.569406         0.433768      0.828462
# 1  27/03/2020 até 25/07/2020  0.491662         0.342513      0.870897
# 2  26/04/2020 até 24/08/2020  0.443511         0.301014      0.842199
# 3  26/05/2020 até 23/09/2020  0.454918         0.314448      0.822222
# 4  25/06/2020 até 23/10/2020  0.445516         0.328592      0.691617
#
#    roc_auc score
# 0       0.719963
# 1       0.677515
# 2       0.685214
# 3       0.702370
# 4       0.642360

# %% [markdown]
# ### Tabelas Ordenadas pelas métricas:

# %% [markdown]
# #### f1 score:

# %%
metricas_120_xg_final_f1 = metricas_120_xg_final.sort_values(by=['f1 score'], ascending=False)
metricas_120_xg_final_f1.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 8   23/10/2020 até 20/02/2021  0.575392         0.461315      0.764423
# 9   22/11/2020 até 22/03/2021  0.571568         0.474068      0.719557
# 0   26/02/2020 até 25/06/2020  0.569406         0.433768      0.828462
# 10  22/12/2020 até 21/04/2021  0.556282         0.464101      0.694158
# 7   23/09/2020 até 21/01/2021  0.556072         0.488345      0.645609
#
#     roc_auc score
# 8        0.660652
# 9        0.666854
# 0        0.719963
# 10       0.650658
# 7        0.644783

# %% [markdown]
# #### Precision score:

# %%
metricas_120_xg_final_precision = metricas_120_xg_final.sort_values(by=['precision score'], ascending=False)
metricas_120_xg_final_precision.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 23  16/01/2022 até 16/05/2022  0.549419         0.508065      0.598101
# 7   23/09/2020 até 21/01/2021  0.556072         0.488345      0.645609
# 9   22/11/2020 até 22/03/2021  0.571568         0.474068      0.719557
# 10  22/12/2020 até 21/04/2021  0.556282         0.464101      0.694158
# 8   23/10/2020 até 20/02/2021  0.575392         0.461315      0.764423
#
#     roc_auc score
# 23       0.654043
# 7        0.644783
# 9        0.666854
# 10       0.650658
# 8        0.660652

# %% [markdown]
# #### Recall score:

# %%
metricas_120_xg_final_recall = metricas_120_xg_final.sort_values(by=['recall score'], ascending=False)
metricas_120_xg_final_recall.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 1   27/03/2020 até 25/07/2020  0.491662         0.342513      0.870897
# 2   26/04/2020 até 24/08/2020  0.443511         0.301014      0.842199
# 0   26/02/2020 até 25/06/2020  0.569406         0.433768      0.828462
# 3   26/05/2020 até 23/09/2020  0.454918         0.314448      0.822222
# 13  22/03/2021 até 20/07/2021  0.516975         0.379174      0.812121
#
#     roc_auc score
# 1        0.677515
# 2        0.685214
# 0        0.719963
# 3        0.702370
# 13       0.636792

# %% [markdown]
# #### AUC ROC score:

# %%
metricas_120_xg_final_auc_roc_score = metricas_120_xg_final.sort_values(by=['roc_auc score'], ascending=False)
metricas_120_xg_final_auc_roc_score.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 24  15/02/2022 até 15/06/2022  0.485477         0.353474      0.774834
# 0   26/02/2020 até 25/06/2020  0.569406         0.433768      0.828462
# 3   26/05/2020 até 23/09/2020  0.454918         0.314448      0.822222
# 2   26/04/2020 até 24/08/2020  0.443511         0.301014      0.842199
# 1   27/03/2020 até 25/07/2020  0.491662         0.342513      0.870897
#
#     roc_auc score
# 24       0.738599
# 0        0.719963
# 3        0.702370
# 2        0.685214
# 1        0.677515

# %% [markdown]
# ### Adicionando nas tabelas finais:

# %%
ranking_f1_120 = ranking_f1_120.append({'Modelo' : 'XGBoost', 'Período' : '23/10/2020 até 20/02/2021', 'f1 score' : 0.575392}, ignore_index = True)
ranking_precision_120 = ranking_precision_120.append({'Modelo' : 'XGBoost', 'Período' : '16/01/2022 até 16/05/2022', 'precision score' : 0.508065}, ignore_index = True)
ranking_recall_120 = ranking_recall_120.append({'Modelo' : 'XGBoost', 'Período' : '27/03/2020 até 25/07/2020', 'recall score' : 0.870897}, ignore_index = True)
ranking_auc_roc_score_120 = ranking_auc_roc_score_120.append({'Modelo' : 'XGBoost', 'Período' : '15/02/2022 até 15/06/2022', 'auc roc score' : 0.738599}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\4015791558.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_f1_120 = ranking_f1_120.append({'Modelo' : 'XGBoost', 'Período' : '23/10/2020 até 20/02/2021', 'f1 score' : 0.575392}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\4015791558.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_precision_120 = ranking_precision_120.append({'Modelo' : 'XGBoost', 'Período' : '16/01/2022 até 16/05/2022', 'precision score' : 0.508065}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\4015791558.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# ## Random Forest:

# %% [markdown]
# #### 90 Dias:

# %%
metricas_90_rf = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_90_rf_final.csv")
metricas_90_rf
# Out:
#                      Períodos  accuracy score  f1 score  f1 score macro  \
# 0   26/02/2020 até 26/05/2020        0.777664  0.500383        0.678700
# 1   27/03/2020 até 25/06/2020        0.672660  0.537383        0.642053
# 2   26/04/2020 até 25/07/2020        0.652070  0.446835        0.596530
# 3   26/05/2020 até 24/08/2020        0.715626  0.372671        0.594406
# 4   25/06/2020 até 23/09/2020        0.743978  0.365188        0.602421
# 5   25/07/2020 até 23/10/2020        0.715976  0.373913        0.595120
# 6   24/08/2020 até 22/11/2020        0.678899  0.337121        0.562628
# 7   23/09/2020 até 22/12/2020        0.670498  0.429708        0.599014
# 8   23/10/2020 até 21/01/2021        0.681694  0.544922        0.650087
# 9   22/11/2020 até 20/02/2021        0.692415  0.550813        0.658475
# 10  22/12/2020 até 22/03/2021        0.693406  0.514419        0.645200
# 11  21/01/2021 até 21/04/2021        0.693247  0.459976        0.622879
# ...

# %%
metricas_90_rf_final = metricas_90_rf.drop(['accuracy score', 'f1 score macro', 'f1 score micro', 'f1 score weighted', 'precision score macro', 'precision score micro', 'precision score weighted', 'recall score macro', 'recall score micro', 'recall score weighted'], axis=1)
metricas_90_rf_final.head(5)
# Out:
#                     Períodos  f1 score  precision score  recall score  \
# 0  26/02/2020 até 26/05/2020  0.500383         0.517989      0.483935
# 1  27/03/2020 até 25/06/2020  0.537383         0.434372      0.704441
# 2  26/04/2020 até 25/07/2020  0.446835         0.338772      0.656134
# 3  26/05/2020 até 24/08/2020  0.372671         0.318021      0.450000
# 4  25/06/2020 até 23/09/2020  0.365188         0.337539      0.397770
#
#    roc_auc score
# 0       0.674685
# 1       0.682676
# 2       0.653548
# 3       0.613504
# 4       0.610202

# %% [markdown]
# ### Tabelas Ordenadas pelas métricas:

# %% [markdown]
# #### f1 score:

# %%
metricas_90_rf_final_f1 = metricas_90_rf_final.sort_values(by=['f1 score'], ascending=False)
metricas_90_rf_final_f1.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 9   22/11/2020 até 20/02/2021  0.550813         0.544177      0.557613
# 15  21/05/2021 até 19/08/2021  0.550318         0.542714      0.558140
# 8   23/10/2020 até 21/01/2021  0.544922         0.537572      0.552475
# 1   27/03/2020 até 25/06/2020  0.537383         0.434372      0.704441
# 24  15/02/2022 até 16/05/2022  0.515306         0.495098      0.537234
#
#     roc_auc score
# 9        0.659459
# 15       0.657574
# 8        0.651107
# 1        0.682676
# 24       0.658574

# %% [markdown]
# #### Precision score:

# %%
metricas_90_rf_final_precision = metricas_90_rf_final.sort_values(by=['precision score'], ascending=False)
metricas_90_rf_final_precision.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 23  16/01/2022 até 16/04/2022  0.417910         0.556818      0.334471
# 9   22/11/2020 até 20/02/2021  0.550813         0.544177      0.557613
# 15  21/05/2021 até 19/08/2021  0.550318         0.542714      0.558140
# 8   23/10/2020 até 21/01/2021  0.544922         0.537572      0.552475
# 11  21/01/2021 até 21/04/2021  0.459976         0.536212      0.402720
#
#     roc_auc score
# 23       0.587481
# 9        0.659459
# 15       0.657574
# 8        0.651107
# 11       0.617734

# %% [markdown]
# #### Recall score:

# %%
metricas_90_rf_final_recall = metricas_90_rf_final.sort_values(by=['recall score'], ascending=False)
metricas_90_rf_final_recall.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 1   27/03/2020 até 25/06/2020  0.537383         0.434372      0.704441
# 2   26/04/2020 até 25/07/2020  0.446835         0.338772      0.656134
# 17  20/07/2021 até 18/10/2021  0.471698         0.373134      0.641026
# 25  17/03/2022 até 15/06/2022  0.348214         0.240741      0.629032
# 15  21/05/2021 até 19/08/2021  0.550318         0.542714      0.558140
#
#     roc_auc score
# 1        0.682676
# 2        0.653548
# 17       0.628146
# 25       0.704695
# 15       0.657574

# %% [markdown]
# #### AUC ROC score:

# %%
metricas_90_rf_final_roc_auc_score = metricas_90_rf_final.sort_values(by=['roc_auc score'], ascending=False)
metricas_90_rf_final_roc_auc_score.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 25  17/03/2022 até 15/06/2022  0.348214         0.240741      0.629032
# 1   27/03/2020 até 25/06/2020  0.537383         0.434372      0.704441
# 0   26/02/2020 até 26/05/2020  0.500383         0.517989      0.483935
# 9   22/11/2020 até 20/02/2021  0.550813         0.544177      0.557613
# 24  15/02/2022 até 16/05/2022  0.515306         0.495098      0.537234
#
#     roc_auc score
# 25       0.704695
# 1        0.682676
# 0        0.674685
# 9        0.659459
# 24       0.658574

# %% [markdown]
# ### Adicionando nas tabelas finais:

# %%
ranking_f1_90 = ranking_f1_90.append({'Modelo' : 'Random Forest', 'Período' : '22/11/2020 até 20/02/2021', 'f1 score' : 0.550813}, ignore_index = True)
ranking_precision_90 = ranking_precision_90.append({'Modelo' : 'Random Forest', 'Período' : '16/01/2022 até 16/04/2022', 'precision score' : 0.556818}, ignore_index = True)
ranking_recall_90 = ranking_recall_90.append({'Modelo' : 'Random Forest', 'Período' : '27/03/2020 até 25/06/2020', 'recall score' : 0.704441}, ignore_index = True)
ranking_auc_roc_score_90 = ranking_auc_roc_score_90.append({'Modelo' : 'Random Forest', 'Período' : '17/03/2022 até 15/06/2022', 'auc roc score' : 0.704695}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\2864624026.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_f1_90 = ranking_f1_90.append({'Modelo' : 'Random Forest', 'Período' : '22/11/2020 até 20/02/2021', 'f1 score' : 0.550813}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\2864624026.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_precision_90 = ranking_precision_90.append({'Modelo' : 'Random Forest', 'Período' : '16/01/2022 até 16/04/2022', 'precision score' : 0.556818}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\2864624026.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# #### 120 Dias:

# %%
metricas_120_rf = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_120_rf_final.csv")
metricas_120_rf
# Out:
#                      Períodos  accuracy score  f1 score  f1 score macro  \
# 0   26/02/2020 até 25/06/2020        0.714286  0.549880        0.670302
# 1   27/03/2020 até 25/07/2020        0.645769  0.489021        0.608973
# 2   26/04/2020 até 24/08/2020        0.660234  0.414489        0.587584
# 3   26/05/2020 até 23/09/2020        0.726213  0.402848        0.612619
# 4   25/06/2020 até 23/10/2020        0.697456  0.370474        0.585677
# 5   25/07/2020 até 22/11/2020        0.688421  0.363897        0.578789
# 6   24/08/2020 até 22/12/2020        0.656195  0.339665        0.553631
# 7   23/09/2020 até 21/01/2021        0.674283  0.498774        0.628765
# 8   23/10/2020 até 20/02/2021        0.690590  0.548837        0.656700
# 9   22/11/2020 até 22/03/2021        0.690982  0.507348        0.641119
# 10  22/12/2020 até 21/04/2021        0.685222  0.470029        0.623077
# 11  21/01/2021 até 21/05/2021        0.685046  0.481370        0.627613
# ...

# %%
metricas_120_rf_final = metricas_120_rf.drop(['accuracy score', 'f1 score macro', 'f1 score micro', 'f1 score weighted', 'precision score macro', 'precision score micro', 'precision score weighted', 'recall score macro', 'recall score micro', 'recall score weighted'], axis=1)
metricas_120_rf_final.head(5)
# Out:
#                     Períodos  f1 score  precision score  recall score  \
# 0  26/02/2020 até 25/06/2020  0.549880         0.471111      0.660278
# 1  27/03/2020 até 25/07/2020  0.489021         0.370558      0.718818
# 2  26/04/2020 até 24/08/2020  0.414489         0.311607      0.618794
# 3  26/05/2020 até 23/09/2020  0.402848         0.342561      0.488889
# 4  25/06/2020 até 23/10/2020  0.370474         0.346354      0.398204
#
#    roc_auc score
# 0       0.696984
# 1       0.671023
# 2       0.644513
# 3       0.635186
# 4       0.590912

# %% [markdown]
# ### Tabelas Ordenadas pelas métricas:

# %% [markdown]
# #### f1 score:

# %%
metricas_120_rf_final_f1 = metricas_120_rf_final.sort_values(by=['f1 score'], ascending=False)
metricas_120_rf_final_f1.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 25/06/2020  0.549880         0.471111      0.660278
# 8   23/10/2020 até 20/02/2021  0.548837         0.531532      0.567308
# 14  21/04/2021 até 19/08/2021  0.541379         0.512235      0.574040
# 15  21/05/2021 até 18/09/2021  0.534005         0.498824      0.574526
# 9   22/11/2020 até 22/03/2021  0.507348         0.527926      0.488315
#
#     roc_auc score
# 0        0.696984
# 8        0.659549
# 14       0.662020
# 15       0.649131
# 9        0.638628

# %% [markdown]
# #### Precision score:

# %%
metricas_120_rf_final_precision = metricas_120_rf_final.sort_values(by=['precision score'], ascending=False)
metricas_120_rf_final_precision.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 23  16/01/2022 até 16/05/2022  0.443623         0.533333      0.379747
# 8   23/10/2020 até 20/02/2021  0.548837         0.531532      0.567308
# 7   23/09/2020 até 21/01/2021  0.498774         0.531359      0.469954
# 9   22/11/2020 até 22/03/2021  0.507348         0.527926      0.488315
# 10  22/12/2020 até 21/04/2021  0.470029         0.526652      0.424399
#
#     roc_auc score
# 23       0.606672
# 8        0.659549
# 7        0.625893
# 9        0.638628
# 10       0.618726

# %% [markdown]
# #### Recall score:

# %%
metricas_120_rf_final_recall = metricas_120_rf_final.sort_values(by=['recall score'], ascending=False)
metricas_120_rf_final_recall.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 1   27/03/2020 até 25/07/2020  0.489021         0.370558      0.718818
# 0   26/02/2020 até 25/06/2020  0.549880         0.471111      0.660278
# 2   26/04/2020 até 24/08/2020  0.414489         0.311607      0.618794
# 16  20/06/2021 até 18/10/2021  0.481390         0.395918      0.613924
# 15  21/05/2021 até 18/09/2021  0.534005         0.498824      0.574526
#
#     roc_auc score
# 1        0.671023
# 0        0.696984
# 2        0.644513
# 16       0.627350
# 15       0.649131

# %% [markdown]
# #### AUC ROC score:

# %%
metricas_120_rf_final_auc_roc_score = metricas_120_rf_final.sort_values(by=['roc_auc score'], ascending=False)
metricas_120_rf_final_auc_roc_score.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 25/06/2020  0.549880         0.471111      0.660278
# 24  15/02/2022 até 15/06/2022  0.446328         0.389163      0.523179
# 1   27/03/2020 até 25/07/2020  0.489021         0.370558      0.718818
# 14  21/04/2021 até 19/08/2021  0.541379         0.512235      0.574040
# 8   23/10/2020 até 20/02/2021  0.548837         0.531532      0.567308
#
#     roc_auc score
# 0        0.696984
# 24       0.675359
# 1        0.671023
# 14       0.662020
# 8        0.659549

# %% [markdown]
# #### Adicionando nas tabelas finais:

# %%
ranking_f1_120 = ranking_f1_120.append({'Modelo' : 'Random Forest', 'Período' : '26/02/2020 até 25/06/2020', 'f1 score' : 0.549880}, ignore_index = True)
ranking_precision_120 = ranking_precision_120.append({'Modelo' : 'Random Forest', 'Período' : '16/01/2022 até 16/05/2022', 'precision score' : 0.533333}, ignore_index = True)
ranking_recall_120 = ranking_recall_120.append({'Modelo' : 'Random Forest', 'Período' : '27/03/2020 até 25/07/2020', 'recall score' : 0.718818}, ignore_index = True)
ranking_auc_roc_score_120 = ranking_auc_roc_score_120.append({'Modelo' : 'Random Forest', 'Período' : '26/02/2020 até 25/06/2020', 'auc roc score' : 0.696984}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\1833015762.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_f1_120 = ranking_f1_120.append({'Modelo' : 'Random Forest', 'Período' : '26/02/2020 até 25/06/2020', 'f1 score' : 0.549880}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\1833015762.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_precision_120 = ranking_precision_120.append({'Modelo' : 'Random Forest', 'Período' : '16/01/2022 até 16/05/2022', 'precision score' : 0.533333}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\1833015762.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# ## SVM:

# %% [markdown]
# #### 90 Dias:

# %%
metricas_90_svm = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_90_svm_final.csv")
metricas_90_svm
# Out:
#                      Períodos  accuracy score  f1 score  f1 score macro  \
# 0   26/02/2020 até 26/05/2020        0.741271  0.594546        0.702284
# 1   27/03/2020 até 25/06/2020        0.646621  0.566430        0.634104
# 2   26/04/2020 até 25/07/2020        0.653264  0.489748        0.613581
# 3   26/05/2020 até 24/08/2020        0.696387  0.411283        0.603365
# 4   25/06/2020 até 23/09/2020        0.668273  0.362434        0.569124
# 5   25/07/2020 até 23/10/2020        0.641026  0.399340        0.571681
# 6   24/08/2020 até 22/11/2020        0.665138  0.412238        0.589057
# 7   23/09/2020 até 22/12/2020        0.655172  0.451220        0.599911
# 8   23/10/2020 até 21/01/2021        0.683060  0.578182        0.662176
# 9   22/11/2020 até 20/02/2021        0.679889  0.559387        0.654010
# 10  22/12/2020 até 22/03/2021        0.681594  0.515356        0.639136
# 11  21/01/2021 até 21/04/2021        0.669834  0.463912        0.612686
# ...

# %%
metricas_90_svm_final = metricas_90_svm.drop(['accuracy score', 'f1 score macro', 'f1 score micro', 'f1 score weighted', 'precision score macro', 'precision score micro', 'precision score weighted', 'recall score macro', 'recall score micro', 'recall score weighted'], axis=1)
metricas_90_svm_final.head(5)
# Out:
#                     Períodos  f1 score  precision score  recall score  \
# 0  26/02/2020 até 26/05/2020  0.594546         0.464883      0.824518
# 1  27/03/2020 até 25/06/2020  0.566430         0.423427      0.855283
# 2  26/04/2020 até 25/07/2020  0.489748         0.357571      0.776952
# 3  26/05/2020 até 24/08/2020  0.411283         0.323319      0.565000
# 4  25/06/2020 até 23/09/2020  0.362434         0.281314      0.509294
#
#    roc_auc score
# 0       0.770457
# 1       0.712385
# 2       0.698253
# 3       0.645874
# 4       0.606843

# %% [markdown]
# ### Tabelas Ordenadas pelas métricas:

# %% [markdown]
# #### f1 score:

# %%
metricas_90_svm_final_f1 = metricas_90_svm_final.sort_values(by=['f1 score'], ascending=False)
metricas_90_svm_final_f1.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 26/05/2020  0.594546         0.464883      0.824518
# 8   23/10/2020 até 21/01/2021  0.578182         0.534454      0.629703
# 1   27/03/2020 até 25/06/2020  0.566430         0.423427      0.855283
# 9   22/11/2020 até 20/02/2021  0.559387         0.523297      0.600823
# 13  22/03/2021 até 20/06/2021  0.555928         0.485826      0.649673
#
#     roc_auc score
# 0        0.770457
# 8        0.670430
# 1        0.712385
# 9        0.660559
# 13       0.685977

# %% [markdown]
# #### Precision score:

# %%
metricas_90_svm_final_precision = metricas_90_svm_final.sort_values(by=['precision score'], ascending=False)
metricas_90_svm_final_precision.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 23  16/01/2022 até 16/04/2022  0.431772         0.535354      0.361775
# 8   23/10/2020 até 21/01/2021  0.578182         0.534454      0.629703
# 15  21/05/2021 até 19/08/2021  0.534704         0.531969      0.537468
# 9   22/11/2020 até 20/02/2021  0.559387         0.523297      0.600823
# 10  22/12/2020 até 22/03/2021  0.515356         0.508124      0.522796
#
#     roc_auc score
# 23       0.586818
# 8        0.670430
# 15       0.646571
# 9        0.660559
# 10       0.640219

# %% [markdown]
# #### Recall score:

# %%
metricas_90_svm_final_recall = metricas_90_svm_final.sort_values(by=['recall score'], ascending=False)
metricas_90_svm_final_recall.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 1   27/03/2020 até 25/06/2020  0.566430         0.423427      0.855283
# 0   26/02/2020 até 26/05/2020  0.594546         0.464883      0.824518
# 2   26/04/2020 até 25/07/2020  0.489748         0.357571      0.776952
# 25  17/03/2022 até 15/06/2022  0.354244         0.229665      0.774194
# 17  20/07/2021 até 18/10/2021  0.469325         0.366029      0.653846
#
#     roc_auc score
# 1        0.712385
# 0        0.770457
# 2        0.698253
# 25       0.743347
# 17       0.624633

# %% [markdown]
# #### AUC ROC score:

# %%
metricas_90_svm_final_auc_roc_score = metricas_90_svm_final.sort_values(by=['roc_auc score'], ascending=False)
metricas_90_svm_final_auc_roc_score.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 26/05/2020  0.594546         0.464883      0.824518
# 25  17/03/2022 até 15/06/2022  0.354244         0.229665      0.774194
# 1   27/03/2020 até 25/06/2020  0.566430         0.423427      0.855283
# 2   26/04/2020 até 25/07/2020  0.489748         0.357571      0.776952
# 13  22/03/2021 até 20/06/2021  0.555928         0.485826      0.649673
#
#     roc_auc score
# 0        0.770457
# 25       0.743347
# 1        0.712385
# 2        0.698253
# 13       0.685977

# %% [markdown]
# #### Adicionando nas tabelas finais:

# %%
ranking_f1_90 = ranking_f1_90.append({'Modelo' : 'SVM', 'Período' : '26/02/2020 até 26/05/2020', 'f1 score' : 0.594546}, ignore_index = True)
ranking_precision_90 = ranking_precision_90.append({'Modelo' : 'SVM', 'Período' : '16/01/2022 até 16/04/2022', 'precision score' : 0.535354}, ignore_index = True)
ranking_recall_90 = ranking_recall_90.append({'Modelo' : 'SVM', 'Período' : '27/03/2020 até 25/06/2020', 'recall score' : 0.855283}, ignore_index = True)
ranking_auc_roc_score_90 = ranking_auc_roc_score_90.append({'Modelo' : 'SVM', 'Período' : '26/02/2020 até 26/05/2020', 'auc roc score' : 0.770457}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\1912597540.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_f1_90 = ranking_f1_90.append({'Modelo' : 'SVM', 'Período' : '26/02/2020 até 26/05/2020', 'f1 score' : 0.594546}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\1912597540.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_precision_90 = ranking_precision_90.append({'Modelo' : 'SVM', 'Período' : '16/01/2022 até 16/04/2022', 'precision score' : 0.535354}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\1912597540.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# #### 120 Dias:

# %%
metricas_120_svm = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_120_svm_final.csv")
metricas_120_svm
# Out:
#                      Períodos  accuracy score  f1 score  f1 score macro  \
# 0   26/02/2020 até 25/06/2020        0.682751  0.586019        0.664429
# 1   27/03/2020 até 25/07/2020        0.633385  0.517815        0.611041
# 2   26/04/2020 até 24/08/2020        0.661957  0.455303        0.605118
# 3   26/05/2020 até 23/09/2020        0.680037  0.423529        0.601048
# 4   25/06/2020 até 23/10/2020        0.647925  0.416851        0.582347
# 5   25/07/2020 até 22/11/2020        0.652632  0.453039        0.599270
# 6   24/08/2020 até 22/12/2020        0.663758  0.429980        0.595766
# 7   23/09/2020 até 21/01/2021        0.684378  0.533019        0.647328
# 8   23/10/2020 até 20/02/2021        0.679426  0.551005        0.650864
# 9   22/11/2020 até 22/03/2021        0.675752  0.526624        0.640026
# 10  22/12/2020 até 21/04/2021        0.694546  0.535453        0.653961
# 11  21/01/2021 até 21/05/2021        0.676203  0.488706        0.625895
# ...

# %%
metricas_120_svm_final = metricas_120_svm.drop(['accuracy score', 'f1 score macro', 'f1 score micro', 'f1 score weighted', 'precision score macro', 'precision score micro', 'precision score weighted', 'recall score macro', 'recall score micro', 'recall score weighted'], axis=1)
metricas_120_svm_final.head(5)
# Out:
#                     Períodos  f1 score  precision score  recall score  \
# 0  26/02/2020 até 25/06/2020  0.586019         0.447275      0.849545
# 1  27/03/2020 até 25/07/2020  0.517815         0.375307      0.834792
# 2  26/04/2020 até 24/08/2020  0.455303         0.331447      0.726950
# 3  26/05/2020 até 23/09/2020  0.423529         0.321019      0.622222
# 4  25/06/2020 até 23/10/2020  0.416851         0.330986      0.562874
#
#    roc_auc score
# 0       0.736186
# 1       0.703014
# 2       0.686615
# 3       0.657862
# 4       0.617644

# %% [markdown]
# ### Tabelas Ordenadas pelas métricas:

# %% [markdown]
# #### f1 score:

# %%
metricas_120_svm_final_f1 = metricas_120_svm_final.sort_values(by=['f1 score'], ascending=False)
metricas_120_svm_final_f1.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 25/06/2020  0.586019         0.447275      0.849545
# 15  21/05/2021 até 18/09/2021  0.578256         0.517094      0.655827
# 14  21/04/2021 até 19/08/2021  0.555461         0.517350      0.599634
# 8   23/10/2020 até 20/02/2021  0.551005         0.514604      0.592949
# 13  22/03/2021 até 20/07/2021  0.541408         0.472448      0.633939
#
#     roc_auc score
# 0        0.736186
# 15       0.681350
# 14       0.671891
# 8        0.657652
# 13       0.673622

# %% [markdown]
# #### Precision score:

# %%
metricas_120_svm_final_precision = metricas_120_svm_final.sort_values(by=['precision score'], ascending=False)
metricas_120_svm_final_precision.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 7   23/09/2020 até 21/01/2021  0.533019         0.544141      0.522342
# 10  22/12/2020 até 21/04/2021  0.535453         0.535684      0.535223
# 23  16/01/2022 até 16/05/2022  0.448833         0.518672      0.395570
# 14  21/04/2021 até 19/08/2021  0.555461         0.517350      0.599634
# 15  21/05/2021 até 18/09/2021  0.578256         0.517094      0.655827
#
#     roc_auc score
# 7        0.646005
# 10       0.653927
# 23       0.605867
# 14       0.671891
# 15       0.681350

# %% [markdown]
# #### Recall score:

# %%
metricas_120_svm_final_recall = metricas_120_svm_final.sort_values(by=['recall score'], ascending=False)
metricas_120_svm_final_recall.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 25/06/2020  0.586019         0.447275      0.849545
# 1   27/03/2020 até 25/07/2020  0.517815         0.375307      0.834792
# 2   26/04/2020 até 24/08/2020  0.455303         0.331447      0.726950
# 16  20/06/2021 até 18/10/2021  0.484234         0.375874      0.680380
# 15  21/05/2021 até 18/09/2021  0.578256         0.517094      0.655827
#
#     roc_auc score
# 0        0.736186
# 1        0.703014
# 2        0.686615
# 16       0.623564
# 15       0.681350

# %% [markdown]
# #### AUC ROC score:

# %%
metricas_120_svm_final_auc_roc_score = metricas_120_svm_final.sort_values(by=['roc_auc score'], ascending=False)
metricas_120_svm_final_auc_roc_score.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 25/06/2020  0.586019         0.447275      0.849545
# 1   27/03/2020 até 25/07/2020  0.517815         0.375307      0.834792
# 2   26/04/2020 até 24/08/2020  0.455303         0.331447      0.726950
# 15  21/05/2021 até 18/09/2021  0.578256         0.517094      0.655827
# 13  22/03/2021 até 20/07/2021  0.541408         0.472448      0.633939
#
#     roc_auc score
# 0        0.736186
# 1        0.703014
# 2        0.686615
# 15       0.681350
# 13       0.673622

# %% [markdown]
# ### Adicionando nas tabelas finais:

# %%
ranking_f1_120 = ranking_f1_120.append({'Modelo' : 'SVM', 'Período' : '26/02/2020 até 25/06/2020', 'f1 score' : 0.586019}, ignore_index = True)
ranking_precision_120 = ranking_precision_120.append({'Modelo' : 'SVM', 'Período' : '23/09/2020 até 21/01/2021', 'precision score' : 0.544141}, ignore_index = True)
ranking_recall_120 = ranking_recall_120.append({'Modelo' : 'SVM', 'Período' : '26/02/2020 até 25/06/2020', 'recall score' : 0.849545}, ignore_index = True)
ranking_auc_roc_score_120 = ranking_auc_roc_score_120.append({'Modelo' : 'SVM', 'Período' : '26/02/2020 até 25/06/2020', 'auc roc score' : 0.736186}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\3143982076.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_f1_120 = ranking_f1_120.append({'Modelo' : 'SVM', 'Período' : '26/02/2020 até 25/06/2020', 'f1 score' : 0.586019}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\3143982076.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_precision_120 = ranking_precision_120.append({'Modelo' : 'SVM', 'Período' : '23/09/2020 até 21/01/2021', 'precision score' : 0.544141}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\3143982076.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# ## KNN:

# %% [markdown]
# #### 90 Dias:

# %%
metricas_90_knn = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_90_knn_final.csv")
metricas_90_knn
# Out:
#                      Períodos  accuracy score  f1 score  f1 score macro  \
# 0   26/02/2020 até 26/05/2020        0.782554  0.532290        0.695320
# 1   27/03/2020 até 25/06/2020        0.678033  0.544444        0.647742
# 2   26/04/2020 até 25/07/2020        0.672771  0.447581        0.607557
# 3   26/05/2020 até 24/08/2020        0.743313  0.306717        0.574608
# 4   25/06/2020 até 23/09/2020        0.743290  0.294896        0.568988
# 5   25/07/2020 até 23/10/2020        0.707101  0.310905        0.562466
# 6   24/08/2020 até 22/11/2020        0.667890  0.287402        0.535447
# 7   23/09/2020 até 22/12/2020        0.643678  0.351464        0.552911
# 8   23/10/2020 até 21/01/2021        0.659153  0.505451        0.622710
# 9   22/11/2020 até 20/02/2021        0.673626  0.529589        0.639861
# 10  22/12/2020 até 22/03/2021        0.688976  0.430631        0.608342
# 11  21/01/2021 até 21/04/2021        0.672548  0.374595        0.576403
# ...

# %%
metricas_90_knn_final = metricas_90_knn.drop(['accuracy score', 'f1 score macro', 'f1 score micro', 'f1 score weighted', 'precision score macro', 'precision score micro', 'precision score weighted', 'recall score macro', 'recall score micro', 'recall score weighted'], axis=1)
metricas_90_knn_final.head(5)
# Out:
#                     Períodos  f1 score  precision score  recall score  \
# 0  26/02/2020 até 26/05/2020  0.532290         0.526877      0.537815
# 1  27/03/2020 até 25/06/2020  0.544444         0.440397      0.712864
# 2  26/04/2020 até 25/07/2020  0.447581         0.350526      0.618959
# 3  26/05/2020 até 24/08/2020  0.306717         0.311054      0.302500
# 4  25/06/2020 até 23/09/2020  0.294896         0.300000      0.289963
#
#    roc_auc score
# 0       0.696751
# 1       0.689010
# 2       0.653198
# 3       0.573838
# 4       0.568123

# %% [markdown]
# ### Tabelas Ordenadas pelas métricas:

# %% [markdown]
# #### f1 score:

# %%
metricas_90_knn_final_f1 = metricas_90_knn_final.sort_values(by=['f1 score'], ascending=False)
metricas_90_knn_final_f1.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 1   27/03/2020 até 25/06/2020  0.544444         0.440397      0.712864
# 0   26/02/2020 até 26/05/2020  0.532290         0.526877      0.537815
# 9   22/11/2020 até 20/02/2021  0.529589         0.516634      0.543210
# 8   23/10/2020 até 21/01/2021  0.505451         0.505952      0.504950
# 15  21/05/2021 até 19/08/2021  0.474926         0.553265      0.416021
#
#     roc_auc score
# 1        0.689010
# 0        0.696751
# 9        0.641742
# 8        0.622653
# 15       0.621228

# %% [markdown]
# #### Precision score:

# %%
metricas_90_knn_final_precision = metricas_90_knn_final.sort_values(by=['precision score'], ascending=False)
metricas_90_knn_final_precision.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 15  21/05/2021 até 19/08/2021  0.474926         0.553265      0.416021
# 10  22/12/2020 até 22/03/2021  0.430631         0.528761      0.363222
# 0   26/02/2020 até 26/05/2020  0.532290         0.526877      0.537815
# 9   22/11/2020 até 20/02/2021  0.529589         0.516634      0.543210
# 12  20/02/2021 até 21/05/2021  0.405424         0.511111      0.335955
#
#     roc_auc score
# 15       0.621228
# 10       0.604100
# 0        0.696751
# 9        0.641742
# 12       0.592833

# %% [markdown]
# #### Recall score:

# %%
metricas_90_knn_final_recall = metricas_90_knn_final.sort_values(by=['recall score'], ascending=False)
metricas_90_knn_final_recall.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 1   27/03/2020 até 25/06/2020  0.544444         0.440397      0.712864
# 25  17/03/2022 até 15/06/2022  0.311284         0.205128      0.645161
# 2   26/04/2020 até 25/07/2020  0.447581         0.350526      0.618959
# 9   22/11/2020 até 20/02/2021  0.529589         0.516634      0.543210
# 17  20/07/2021 até 18/10/2021  0.439446         0.369186      0.542735
#
#     roc_auc score
# 1        0.689010
# 25       0.684188
# 2        0.653198
# 9        0.641742
# 17       0.605719

# %% [markdown]
# #### AUC ROC score:

# %%
metricas_90_knn_final_auc_roc_score = metricas_90_knn_final.sort_values(by=['roc_auc score'], ascending=False)
metricas_90_knn_final_auc_roc_score.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 26/05/2020  0.532290         0.526877      0.537815
# 1   27/03/2020 até 25/06/2020  0.544444         0.440397      0.712864
# 25  17/03/2022 até 15/06/2022  0.311284         0.205128      0.645161
# 2   26/04/2020 até 25/07/2020  0.447581         0.350526      0.618959
# 9   22/11/2020 até 20/02/2021  0.529589         0.516634      0.543210
#
#     roc_auc score
# 0        0.696751
# 1        0.689010
# 25       0.684188
# 2        0.653198
# 9        0.641742

# %% [markdown]
# ### Adicionando nas tabelas finais:

# %%
ranking_f1_90 = ranking_f1_90.append({'Modelo' : 'KNN', 'Período' : '27/03/2020 até 25/06/2020', 'f1 score' : 0.544444}, ignore_index = True)
ranking_precision_90 = ranking_precision_90.append({'Modelo' : 'KNN', 'Período' : '21/05/2021 até 19/08/2021', 'precision score' : 0.553265}, ignore_index = True)
ranking_recall_90 = ranking_recall_90.append({'Modelo' : 'KNN', 'Período' : '27/03/2020 até 25/06/2020', 'recall score' : 0.712864}, ignore_index = True)
ranking_auc_roc_score_90 = ranking_auc_roc_score_90.append({'Modelo' : 'KNN', 'Período' : '26/02/2020 até 26/05/2020', 'auc roc score' : 0.696751}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\4220068369.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_f1_90 = ranking_f1_90.append({'Modelo' : 'KNN', 'Período' : '27/03/2020 até 25/06/2020', 'f1 score' : 0.544444}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\4220068369.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_precision_90 = ranking_precision_90.append({'Modelo' : 'KNN', 'Período' : '21/05/2021 até 19/08/2021', 'precision score' : 0.553265}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\4220068369.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# #### 120 Dias:

# %%
metricas_120_knn = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_120_knn_final.csv")
metricas_120_knn
# Out:
#                      Períodos  accuracy score  f1 score  f1 score macro  \
# 0   26/02/2020 até 25/06/2020        0.677812  0.562887        0.653886
# 1   27/03/2020 até 25/07/2020        0.638287  0.496046        0.606977
# 2   26/04/2020 até 24/08/2020        0.660234  0.444820        0.600017
# 3   26/05/2020 até 23/09/2020        0.751399  0.322745        0.585251
# 4   25/06/2020 até 23/10/2020        0.667336  0.399033        0.584523
# 5   25/07/2020 até 22/11/2020        0.687018  0.324242        0.560295
# 6   24/08/2020 até 22/12/2020        0.655614  0.296912        0.534434
# 7   23/09/2020 até 21/01/2021        0.652497  0.381853        0.570084
# 8   23/10/2020 até 20/02/2021        0.671451  0.469072        0.615598
# 9   22/11/2020 até 22/03/2021        0.694188  0.444283        0.616667
# 10  22/12/2020 até 21/04/2021        0.679571  0.404412        0.592619
# 11  21/01/2021 até 21/05/2021        0.680364  0.388861        0.586225
# ...

# %%
metricas_120_knn_final = metricas_120_knn.drop(['accuracy score', 'f1 score macro', 'f1 score micro', 'f1 score weighted', 'precision score macro', 'precision score micro', 'precision score weighted', 'recall score macro', 'recall score micro', 'recall score weighted'], axis=1)
metricas_120_knn_final.head(5)
# Out:
#                     Períodos  f1 score  precision score  recall score  \
# 0  26/02/2020 até 25/06/2020  0.562887         0.438789      0.784859
# 1  27/03/2020 até 25/07/2020  0.496046         0.369379      0.754923
# 2  26/04/2020 até 24/08/2020  0.444820         0.325908      0.700355
# 3  26/05/2020 até 23/09/2020  0.322745         0.332461      0.313580
# 4  25/06/2020 até 23/10/2020  0.399033         0.334686      0.494012
#
#    roc_auc score
# 0       0.712106
# 1       0.678610
# 2       0.675455
# 3       0.583472
# 4       0.605627

# %% [markdown]
# ### Tabelas Ordenadas pelas métricas:

# %% [markdown]
# #### f1 score:

# %%
metricas_120_knn_final_f1 = metricas_120_knn_final.sort_values(by=['f1 score'], ascending=False)
metricas_120_knn_final_f1.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 25/06/2020  0.562887         0.438789      0.784859
# 1   27/03/2020 até 25/07/2020  0.496046         0.369379      0.754923
# 15  21/05/2021 até 18/09/2021  0.490085         0.513353      0.468835
# 8   23/10/2020 até 20/02/2021  0.469072         0.505556      0.437500
# 14  21/04/2021 até 19/08/2021  0.467861         0.552239      0.405850
#
#     roc_auc score
# 0        0.712106
# 1        0.678610
# 15       0.628062
# 8        0.612545
# 14       0.627674

# %% [markdown]
# #### Precision score:

# %%
metricas_120_knn_final_precision = metricas_120_knn_final.sort_values(by=['precision score'], ascending=False)
metricas_120_knn_final_precision.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 14  21/04/2021 até 19/08/2021  0.467861         0.552239      0.405850
# 9   22/11/2020 até 22/03/2021  0.444283         0.544643      0.375154
# 10  22/12/2020 até 21/04/2021  0.404412         0.520270      0.330756
# 11  21/01/2021 até 21/05/2021  0.388861         0.519256      0.310811
# 15  21/05/2021 até 18/09/2021  0.490085         0.513353      0.468835
#
#     roc_auc score
# 14       0.627674
# 9        0.611774
# 10       0.590641
# 11       0.585440
# 15       0.628062

# %% [markdown]
# #### Recall score:

# %%
metricas_120_knn_final_recall = metricas_120_knn_final.sort_values(by=['recall score'], ascending=False)
metricas_120_knn_final_recall.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 25/06/2020  0.562887         0.438789      0.784859
# 1   27/03/2020 até 25/07/2020  0.496046         0.369379      0.754923
# 2   26/04/2020 até 24/08/2020  0.444820         0.325908      0.700355
# 16  20/06/2021 até 18/10/2021  0.448468         0.400498      0.509494
# 4   25/06/2020 até 23/10/2020  0.399033         0.334686      0.494012
#
#     roc_auc score
# 0        0.712106
# 1        0.678610
# 2        0.675455
# 16       0.608509
# 4        0.605627

# %% [markdown]
# #### AUC ROC score:

# %%
metricas_120_knn_final_auc_roc_score = metricas_120_knn_final.sort_values(by=['roc_auc score'], ascending=False)
metricas_120_knn_final_auc_roc_score.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 25/06/2020  0.562887         0.438789      0.784859
# 1   27/03/2020 até 25/07/2020  0.496046         0.369379      0.754923
# 2   26/04/2020 até 24/08/2020  0.444820         0.325908      0.700355
# 15  21/05/2021 até 18/09/2021  0.490085         0.513353      0.468835
# 14  21/04/2021 até 19/08/2021  0.467861         0.552239      0.405850
#
#     roc_auc score
# 0        0.712106
# 1        0.678610
# 2        0.675455
# 15       0.628062
# 14       0.627674

# %% [markdown]
# ### Adicionando nas tabelas finais:

# %%
ranking_f1_120 = ranking_f1_120.append({'Modelo' : 'KNN', 'Período' : '26/02/2020 até 25/06/2020', 'f1 score' : 0.562887}, ignore_index = True)
ranking_precision_120 = ranking_precision_120.append({'Modelo' : 'KNN', 'Período' : '21/04/2021 até 19/08/2021', 'precision score' : 0.552239}, ignore_index = True)
ranking_recall_120 = ranking_recall_120.append({'Modelo' : 'KNN', 'Período' : '26/02/2020 até 25/06/2020', 'recall score' : 0.784859}, ignore_index = True)
ranking_auc_roc_score_120 = ranking_auc_roc_score_120.append({'Modelo' : 'KNN', 'Período' : '26/02/2020 até 25/06/2020', 'auc roc score' : 0.712106}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\1288813780.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_f1_120 = ranking_f1_120.append({'Modelo' : 'KNN', 'Período' : '26/02/2020 até 25/06/2020', 'f1 score' : 0.562887}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\1288813780.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_precision_120 = ranking_precision_120.append({'Modelo' : 'KNN', 'Período' : '21/04/2021 até 19/08/2021', 'precision score' : 0.552239}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\1288813780.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# ## Gradient Boosting:

# %% [markdown]
# #### 90 Dias:

# %%
metricas_90_gb = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_90_gb_final.csv")
metricas_90_gb
# Out:
#                      Períodos  accuracy score  f1 score  f1 score macro  \
# 0   26/02/2020 até 26/05/2020        0.767884  0.501831        0.675261
# 1   27/03/2020 até 25/06/2020        0.674726  0.537059        0.643171
# 2   26/04/2020 até 25/07/2020        0.664411  0.442829        0.601363
# 3   26/05/2020 até 24/08/2020        0.720788  0.346872        0.584656
# 4   25/06/2020 até 23/09/2020        0.727460  0.331081        0.579974
# 5   25/07/2020 até 23/10/2020        0.703156  0.352688        0.580055
# 6   24/08/2020 até 22/11/2020        0.681651  0.341556        0.565817
# 7   23/09/2020 até 22/12/2020        0.656705  0.424165        0.589812
# 8   23/10/2020 até 21/01/2021        0.655738  0.519084        0.625499
# 9   22/11/2020 até 20/02/2021        0.694502  0.545078        0.657557
# 10  22/12/2020 até 22/03/2021        0.689961  0.512384        0.642556
# 11  21/01/2021 até 21/04/2021        0.684764  0.463316        0.620080
# ...

# %%
metricas_90_gb_final = metricas_90_gb.drop(['accuracy score', 'f1 score macro', 'f1 score micro', 'f1 score weighted', 'precision score macro', 'precision score micro', 'precision score weighted', 'recall score macro', 'recall score micro', 'recall score weighted'], axis=1)
metricas_90_gb_final.head(5)
# Out:
#                     Períodos  f1 score  precision score  recall score  \
# 0  26/02/2020 até 26/05/2020  0.501831         0.495661      0.508156
# 1  27/03/2020 até 25/06/2020  0.537059         0.436008      0.699081
# 2  26/04/2020 até 25/07/2020  0.442829         0.343590      0.622677
# 3  26/05/2020 até 24/08/2020  0.346872         0.309198      0.395000
# 4  25/06/2020 até 23/09/2020  0.331081         0.303406      0.364312
#
#    roc_auc score
# 0       0.676826
# 1       0.682402
# 2       0.649231
# 3       0.595536
# 4       0.587139

# %% [markdown]
# ### Tabelas Ordenadas pelas métricas:

# %% [markdown]
# #### f1 score:

# %%
metricas_90_gb_final_f1 = metricas_90_gb_final.sort_values(by=['f1 score'], ascending=False)
metricas_90_gb_final_f1.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 15  21/05/2021 até 19/08/2021  0.563380         0.558376      0.568475
# 9   22/11/2020 até 20/02/2021  0.545078         0.549061      0.541152
# 1   27/03/2020 até 25/06/2020  0.537059         0.436008      0.699081
# 24  15/02/2022 até 16/05/2022  0.519685         0.512953      0.526596
# 8   23/10/2020 até 21/01/2021  0.519084         0.500921      0.538614
#
#     roc_auc score
# 15       0.668083
# 9        0.657011
# 1        0.682402
# 24       0.662871
# 8        0.628014

# %% [markdown]
# #### Precision score:

# %%
metricas_90_gb_final_precision = metricas_90_gb_final.sort_values(by=['precision score'], ascending=False)
metricas_90_gb_final_precision.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 15  21/05/2021 até 19/08/2021  0.563380         0.558376      0.568475
# 9   22/11/2020 até 20/02/2021  0.545078         0.549061      0.541152
# 10  22/12/2020 até 22/03/2021  0.512384         0.522082      0.503040
# 11  21/01/2021 até 21/04/2021  0.463316         0.517419      0.419456
# 24  15/02/2022 até 16/05/2022  0.519685         0.512953      0.526596
#
#     roc_auc score
# 15       0.668083
# 9        0.657011
# 10       0.641258
# 11       0.615805
# 24       0.662871

# %% [markdown]
# #### Recall score:

# %%
metricas_90_gb_final_recall = metricas_90_gb_final.sort_values(by=['recall score'], ascending=False)
metricas_90_gb_final_recall.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 1   27/03/2020 até 25/06/2020  0.537059         0.436008      0.699081
# 17  20/07/2021 até 18/10/2021  0.484663         0.377990      0.675214
# 2   26/04/2020 até 25/07/2020  0.442829         0.343590      0.622677
# 15  21/05/2021 até 19/08/2021  0.563380         0.558376      0.568475
# 9   22/11/2020 até 20/02/2021  0.545078         0.549061      0.541152
#
#     roc_auc score
# 1        0.682402
# 17       0.639134
# 2        0.649231
# 15       0.668083
# 9        0.657011

# %% [markdown]
# #### AUC ROC score:

# %%
metricas_90_gb_final_auc_roc_score = metricas_90_gb_final.sort_values(by=['roc_auc score'], ascending=False)
metricas_90_gb_final_auc_roc_score.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 1   27/03/2020 até 25/06/2020  0.537059         0.436008      0.699081
# 0   26/02/2020 até 26/05/2020  0.501831         0.495661      0.508156
# 15  21/05/2021 até 19/08/2021  0.563380         0.558376      0.568475
# 24  15/02/2022 até 16/05/2022  0.519685         0.512953      0.526596
# 9   22/11/2020 até 20/02/2021  0.545078         0.549061      0.541152
#
#     roc_auc score
# 1        0.682402
# 0        0.676826
# 15       0.668083
# 24       0.662871
# 9        0.657011

# %% [markdown]
# ### Adicionando nas tabelas finais:

# %%
ranking_f1_90 = ranking_f1_90.append({'Modelo' : 'Gradient Boosting', 'Período' : '21/05/2021 até 19/08/2021', 'f1 score' : 0.563380}, ignore_index = True)
ranking_precision_90 = ranking_precision_90.append({'Modelo' : 'Gradient Boosting', 'Período' : '21/05/2021 até 19/08/2021', 'precision score' : 0.558376}, ignore_index = True)
ranking_recall_90 = ranking_recall_90.append({'Modelo' : 'Gradient Boosting', 'Período' : '27/03/2020 até 25/06/2020', 'recall score' : 0.699081}, ignore_index = True)
ranking_auc_roc_score_90 = ranking_auc_roc_score_90.append({'Modelo' : 'Gradient Boosting', 'Período' : '27/03/2020 até 25/06/2020', 'auc roc score' : 0.682402}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\1901147766.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_f1_90 = ranking_f1_90.append({'Modelo' : 'Gradient Boosting', 'Período' : '21/05/2021 até 19/08/2021', 'f1 score' : 0.563380}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\1901147766.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_precision_90 = ranking_precision_90.append({'Modelo' : 'Gradient Boosting', 'Período' : '21/05/2021 até 19/08/2021', 'precision score' : 0.558376}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\1901147766.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# #### 120 Dias:

# %%
metricas_120_gb = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_120_gb_final.csv")
metricas_120_gb
# Out:
#                      Períodos  accuracy score  f1 score  f1 score macro  \
# 0   26/02/2020 até 25/06/2020        0.718855  0.566975        0.679417
# 1   27/03/2020 até 25/07/2020        0.652507  0.496241        0.615510
# 2   26/04/2020 até 24/08/2020        0.669694  0.408434        0.589658
# 3   26/05/2020 até 23/09/2020        0.739531  0.418891        0.625519
# 4   25/06/2020 até 23/10/2020        0.691099  0.333333        0.566156
# 5   25/07/2020 até 22/11/2020        0.696281  0.384937        0.591646
# 6   24/08/2020 até 22/12/2020        0.663423  0.378436        0.573833
# 7   23/09/2020 até 21/01/2021        0.667017  0.493195        0.622625
# 8   23/10/2020 até 20/02/2021        0.683272  0.533230        0.646774
# 9   22/11/2020 até 22/03/2021        0.716035  0.559166        0.674864
# 10  22/12/2020 até 21/04/2021        0.679595  0.458689        0.615572
# 11  21/01/2021 até 21/05/2021        0.687278  0.478885        0.627748
# ...

# %%
metricas_120_gb_final = metricas_120_gb.drop(['accuracy score', 'f1 score macro', 'f1 score micro', 'f1 score weighted', 'precision score macro', 'precision score micro', 'precision score weighted', 'recall score macro', 'recall score micro', 'recall score weighted'], axis=1)
metricas_120_gb_final.head(5)
# Out:
#                     Períodos  f1 score  precision score  recall score  \
# 0  26/02/2020 até 25/06/2020  0.566975         0.478402      0.695796
# 1  27/03/2020 até 25/07/2020  0.496241         0.377246      0.724895
# 2  26/04/2020 até 24/08/2020  0.408434         0.312731      0.588542
# 3  26/05/2020 até 23/09/2020  0.418891         0.363636      0.493947
# 4  25/06/2020 até 23/10/2020  0.333333         0.318919      0.349112
#
#    roc_auc score
# 0       0.711473
# 1       0.677514
# 2       0.638868
# 3       0.645553
# 4       0.568674

# %% [markdown]
# ### Tabelas Ordenadas pelas métricas:

# %% [markdown]
# #### f1 score:

# %%
metricas_120_gb_final_f1 = metricas_120_gb_final.sort_values(by=['f1 score'], ascending=False)
metricas_120_gb_final_f1.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 25/06/2020  0.566975         0.478402      0.695796
# 9   22/11/2020 até 22/03/2021  0.559166         0.564356      0.554070
# 15  21/05/2021 até 18/09/2021  0.547847         0.508889      0.593264
# 14  21/04/2021 até 19/08/2021  0.540034         0.521382      0.560071
# 8   23/10/2020 até 20/02/2021  0.533230         0.525114      0.541601
#
#     roc_auc score
# 0        0.711473
# 9        0.674051
# 15       0.658161
# 14       0.661066
# 8        0.647966

# %% [markdown]
# #### Precision score:

# %%
metricas_120_gb_final_precision = metricas_120_gb_final.sort_values(by=['precision score'], ascending=False)
metricas_120_gb_final_precision.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 9   22/11/2020 até 22/03/2021  0.559166         0.564356      0.554070
# 8   23/10/2020 até 20/02/2021  0.533230         0.525114      0.541601
# 14  21/04/2021 até 19/08/2021  0.540034         0.521382      0.560071
# 7   23/09/2020 até 21/01/2021  0.493195         0.519393      0.469512
# 11  21/01/2021 até 21/05/2021  0.478885         0.518756      0.444706
#
#     roc_auc score
# 9        0.674051
# 8        0.647966
# 14       0.661066
# 7        0.620298
# 11       0.623888

# %% [markdown]
# #### Recall score:

# %%
metricas_120_gb_final_recall = metricas_120_gb_final.sort_values(by=['recall score'], ascending=False)
metricas_120_gb_final_recall.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 1   27/03/2020 até 25/07/2020  0.496241         0.377246      0.724895
# 0   26/02/2020 até 25/06/2020  0.566975         0.478402      0.695796
# 15  21/05/2021 até 18/09/2021  0.547847         0.508889      0.593264
# 2   26/04/2020 até 24/08/2020  0.408434         0.312731      0.588542
# 16  20/06/2021 até 18/10/2021  0.472362         0.397463      0.582043
#
#     roc_auc score
# 1        0.677514
# 0        0.711473
# 15       0.658161
# 2        0.638868
# 16       0.622183

# %% [markdown]
# #### AUC ROC score:

# %%
metricas_120_gb_final_auc_roc_score = metricas_120_gb_final.sort_values(by=['roc_auc score'], ascending=False)
metricas_120_gb_final_auc_roc_score.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 25/06/2020  0.566975         0.478402      0.695796
# 1   27/03/2020 até 25/07/2020  0.496241         0.377246      0.724895
# 9   22/11/2020 até 22/03/2021  0.559166         0.564356      0.554070
# 24  15/02/2022 até 15/06/2022  0.425414         0.368421      0.503268
# 14  21/04/2021 até 19/08/2021  0.540034         0.521382      0.560071
#
#     roc_auc score
# 0        0.711473
# 1        0.677514
# 9        0.674051
# 24       0.661470
# 14       0.661066

# %% [markdown]
# ### Adicionando nas tabelas finais:

# %%
ranking_f1_120 = ranking_f1_120.append({'Modelo' : 'Gradient Boosting', 'Período' : '26/02/2020 até 25/06/2020', 'f1 score' : 0.566975}, ignore_index = True)
ranking_precision_120 = ranking_precision_120.append({'Modelo' : 'Gradient Boosting', 'Período' : '22/11/2020 até 22/03/2021', 'precision score' : 0.564356}, ignore_index = True)
ranking_recall_120 = ranking_recall_120.append({'Modelo' : 'Gradient Boosting', 'Período' : '27/03/2020 até 25/07/2020', 'recall score' : 0.724895}, ignore_index = True)
ranking_auc_roc_score_120 = ranking_auc_roc_score_120.append({'Modelo' : 'Gradient Boosting', 'Período' : '26/02/2020 até 25/06/2020', 'auc roc score' : 0.711473}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\3343801999.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_f1_120 = ranking_f1_120.append({'Modelo' : 'Gradient Boosting', 'Período' : '26/02/2020 até 25/06/2020', 'f1 score' : 0.566975}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\3343801999.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_precision_120 = ranking_precision_120.append({'Modelo' : 'Gradient Boosting', 'Período' : '22/11/2020 até 22/03/2021', 'precision score' : 0.564356}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_94008\3343801999.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# ## Tabelas finais:

# %% [markdown]
# #### 90 Dias:

# %%
ranking_f1_90
# Out:
#               Modelo                    Período  f1 score
# 0            XGBoost  22/11/2020 até 20/02/2021  0.582838
# 1      Random Forest  22/11/2020 até 20/02/2021  0.550813
# 2                SVM  26/02/2020 até 26/05/2020  0.594546
# 3                KNN  27/03/2020 até 25/06/2020  0.544444
# 4  Gradient Boosting  21/05/2021 até 19/08/2021   0.56338

# %%
ranking_f1_90_final = ranking_f1_90.sort_values(by=['f1 score'],ignore_index=True, ascending=False)
ranking_f1_90_final
# Out:
#               Modelo                    Período  f1 score
# 0                SVM  26/02/2020 até 26/05/2020  0.594546
# 1            XGBoost  22/11/2020 até 20/02/2021  0.582838
# 2  Gradient Boosting  21/05/2021 até 19/08/2021   0.56338
# 3      Random Forest  22/11/2020 até 20/02/2021  0.550813
# 4                KNN  27/03/2020 até 25/06/2020  0.544444

# %%
ranking_precision_90
# Out:
#               Modelo                    Período precision score
# 0            XGBoost  16/01/2022 até 16/04/2022         0.50838
# 1      Random Forest  16/01/2022 até 16/04/2022        0.556818
# 2                SVM  16/01/2022 até 16/04/2022        0.535354
# 3                KNN  21/05/2021 até 19/08/2021        0.553265
# 4  Gradient Boosting  21/05/2021 até 19/08/2021        0.558376

# %%
ranking_precision_90_final = ranking_precision_90.sort_values(by=['precision score'],ignore_index=True, ascending=False)
ranking_precision_90_final
# Out:
#               Modelo                    Período precision score
# 0  Gradient Boosting  21/05/2021 até 19/08/2021        0.558376
# 1      Random Forest  16/01/2022 até 16/04/2022        0.556818
# 2                KNN  21/05/2021 até 19/08/2021        0.553265
# 3                SVM  16/01/2022 até 16/04/2022        0.535354
# 4            XGBoost  16/01/2022 até 16/04/2022         0.50838

# %%
ranking_recall_90
# Out:
#               Modelo                    Período recall score
# 0            XGBoost  26/04/2020 até 25/07/2020     0.879182
# 1      Random Forest  27/03/2020 até 25/06/2020     0.704441
# 2                SVM  27/03/2020 até 25/06/2020     0.855283
# 3                KNN  27/03/2020 até 25/06/2020     0.712864
# 4  Gradient Boosting  27/03/2020 até 25/06/2020     0.699081

# %%
ranking_recall_90_final = ranking_recall_90.sort_values(by=['recall score'],ignore_index=True, ascending=False)
ranking_recall_90_final
# Out:
#               Modelo                    Período recall score
# 0            XGBoost  26/04/2020 até 25/07/2020     0.879182
# 1                SVM  27/03/2020 até 25/06/2020     0.855283
# 2                KNN  27/03/2020 até 25/06/2020     0.712864
# 3      Random Forest  27/03/2020 até 25/06/2020     0.704441
# 4  Gradient Boosting  27/03/2020 até 25/06/2020     0.699081

# %%
ranking_auc_roc_score_90
# Out:
#               Modelo                    Período auc roc score
# 0            XGBoost  26/02/2020 até 26/05/2020      0.730524
# 1      Random Forest  17/03/2022 até 15/06/2022      0.704695
# 2                SVM  26/02/2020 até 26/05/2020      0.770457
# 3                KNN  26/02/2020 até 26/05/2020      0.696751
# 4  Gradient Boosting  27/03/2020 até 25/06/2020      0.682402

# %%
ranking_auc_roc_score_90_final = ranking_auc_roc_score_90.sort_values(by=['auc roc score'],ignore_index=True, ascending=False)
ranking_auc_roc_score_90_final
# Out:
#               Modelo                    Período auc roc score
# 0                SVM  26/02/2020 até 26/05/2020      0.770457
# 1            XGBoost  26/02/2020 até 26/05/2020      0.730524
# 2      Random Forest  17/03/2022 até 15/06/2022      0.704695
# 3                KNN  26/02/2020 até 26/05/2020      0.696751
# 4  Gradient Boosting  27/03/2020 até 25/06/2020      0.682402

# %% [markdown]
# #### 120 Dias:

# %%
ranking_f1_120
# Out:
#               Modelo                    Período  f1 score
# 0            XGBoost  23/10/2020 até 20/02/2021  0.575392
# 1      Random Forest  26/02/2020 até 25/06/2020   0.54988
# 2                SVM  26/02/2020 até 25/06/2020  0.586019
# 3                KNN  26/02/2020 até 25/06/2020  0.562887
# 4  Gradient Boosting  26/02/2020 até 25/06/2020  0.566975

# %%
ranking_f1_120_final = ranking_f1_120.sort_values(by=['f1 score'],ignore_index=True, ascending=False)
ranking_f1_120_final
# Out:
#               Modelo                    Período  f1 score
# 0                SVM  26/02/2020 até 25/06/2020  0.586019
# 1            XGBoost  23/10/2020 até 20/02/2021  0.575392
# 2  Gradient Boosting  26/02/2020 até 25/06/2020  0.566975
# 3                KNN  26/02/2020 até 25/06/2020  0.562887
# 4      Random Forest  26/02/2020 até 25/06/2020   0.54988

# %%
ranking_precision_120
# Out:
#               Modelo                    Período precision score
# 0            XGBoost  16/01/2022 até 16/05/2022        0.508065
# 1      Random Forest  16/01/2022 até 16/05/2022        0.533333
# 2                SVM  23/09/2020 até 21/01/2021        0.544141
# 3                KNN  21/04/2021 até 19/08/2021        0.552239
# 4  Gradient Boosting  22/11/2020 até 22/03/2021        0.564356

# %%
ranking_precision_120_final = ranking_precision_120.sort_values(by=['precision score'],ignore_index=True, ascending=False)
ranking_precision_120_final
# Out:
#               Modelo                    Período precision score
# 0  Gradient Boosting  22/11/2020 até 22/03/2021        0.564356
# 1                KNN  21/04/2021 até 19/08/2021        0.552239
# 2                SVM  23/09/2020 até 21/01/2021        0.544141
# 3      Random Forest  16/01/2022 até 16/05/2022        0.533333
# 4            XGBoost  16/01/2022 até 16/05/2022        0.508065

# %%
ranking_recall_120
# Out:
#               Modelo                    Período recall score
# 0            XGBoost  27/03/2020 até 25/07/2020     0.870897
# 1      Random Forest  27/03/2020 até 25/07/2020     0.718818
# 2                SVM  26/02/2020 até 25/06/2020     0.849545
# 3                KNN  26/02/2020 até 25/06/2020     0.784859
# 4  Gradient Boosting  27/03/2020 até 25/07/2020     0.724895

# %%
ranking_recall_120_final = ranking_recall_120.sort_values(by=['recall score'],ignore_index=True, ascending=False)
ranking_recall_120_final
# Out:
#               Modelo                    Período recall score
# 0            XGBoost  27/03/2020 até 25/07/2020     0.870897
# 1                SVM  26/02/2020 até 25/06/2020     0.849545
# 2                KNN  26/02/2020 até 25/06/2020     0.784859
# 3  Gradient Boosting  27/03/2020 até 25/07/2020     0.724895
# 4      Random Forest  27/03/2020 até 25/07/2020     0.718818

# %%
ranking_auc_roc_score_120
# Out:
#               Modelo                    Período auc roc score
# 0            XGBoost  15/02/2022 até 15/06/2022      0.738599
# 1      Random Forest  26/02/2020 até 25/06/2020      0.696984
# 2                SVM  26/02/2020 até 25/06/2020      0.736186
# 3                KNN  26/02/2020 até 25/06/2020      0.712106
# 4  Gradient Boosting  26/02/2020 até 25/06/2020      0.711473

# %%
ranking_auc_roc_score_120_final = ranking_auc_roc_score_120.sort_values(by=['auc roc score'],ignore_index=True, ascending=False)
ranking_auc_roc_score_120_final
# Out:
#               Modelo                    Período auc roc score
# 0            XGBoost  15/02/2022 até 15/06/2022      0.738599
# 1                SVM  26/02/2020 até 25/06/2020      0.736186
# 2                KNN  26/02/2020 até 25/06/2020      0.712106
# 3  Gradient Boosting  26/02/2020 até 25/06/2020      0.711473
# 4      Random Forest  26/02/2020 até 25/06/2020      0.696984
