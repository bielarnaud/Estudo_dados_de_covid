# %%
import pandas as pd

# %%
ranking_f1_90 = pd.DataFrame(columns = ['Modelo', 'Período', 'f1 score'])
ranking_precision_90 = pd.DataFrame(columns = ['Modelo', 'Período', 'precision score'])
ranking_recall_90 = pd.DataFrame(columns = ['Modelo', 'Período', 'recall score'])
ranking_roc_auc_score_90 = pd.DataFrame(columns = ['Modelo', 'Período', 'roc_auc score'])

# %%
ranking_f1_120 = pd.DataFrame(columns = ['Modelo', 'Período', 'f1 score'])
ranking_precision_120 = pd.DataFrame(columns = ['Modelo', 'Período', 'precision score'])
ranking_recall_120 = pd.DataFrame(columns = ['Modelo', 'Período', 'recall score'])
ranking_roc_auc_score_120 = pd.DataFrame(columns = ['Modelo', 'Período', 'roc_auc score'])

# %% [markdown]
# # Métricas de cada modelo:

# %% [markdown]
# ## XGBoost:

# %% [markdown]
# #### 90 Dias:

# %%
metricas_90_xg = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_90_xg_final.csv")
metricas_90_xg
# Out:
#                      Períodos  accuracy score  f1 score  f1 score macro  \
# 0   26/02/2020 até 26/05/2020        0.740930  0.564602        0.690104
# 1   27/03/2020 até 25/06/2020        0.583178  0.532994        0.578309
# 2   26/04/2020 até 25/07/2020        0.568471  0.464956        0.551691
# 3   26/05/2020 até 24/08/2020        0.613796  0.435141        0.570868
# 4   25/06/2020 até 23/09/2020        0.638679  0.412094        0.575645
# 5   25/07/2020 até 23/10/2020        0.634122  0.424806        0.578274
# 6   24/08/2020 até 22/11/2020        0.651376  0.425982        0.587826
# 7   23/09/2020 até 22/12/2020        0.650575  0.527950        0.625289
# 8   23/10/2020 até 21/01/2021        0.623634  0.556718        0.614857
# 9   22/11/2020 até 20/02/2021        0.657620  0.584459        0.646668
# 10  22/12/2020 até 22/03/2021        0.657480  0.578182        0.644932
# 11  21/01/2021 até 21/04/2021        0.651849  0.553525        0.634104
# ...

# %%
metricas_90_xg_final = metricas_90_xg.drop(['accuracy score', 'f1 score macro', 'f1 score micro', 'f1 score weighted', 'precision score macro', 'precision score micro', 'precision score weighted', 'recall score macro', 'recall score micro', 'recall score weighted'], axis=1)
metricas_90_xg_final
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 26/05/2020  0.564602         0.460268      0.460268
# 1   27/03/2020 até 25/06/2020  0.532994         0.382011      0.382011
# 2   26/04/2020 até 25/07/2020  0.464956         0.316532      0.316532
# 3   26/05/2020 até 24/08/2020  0.435141         0.299905      0.299905
# 4   25/06/2020 até 23/09/2020  0.412094         0.294872      0.294872
# 5   25/07/2020 até 23/10/2020  0.424806         0.339109      0.339109
# 6   24/08/2020 até 22/11/2020  0.425982         0.408696      0.408696
# 7   23/09/2020 até 22/12/2020  0.527950         0.481132      0.481132
# 8   23/10/2020 até 21/01/2021  0.556718         0.468835      0.468835
# 9   22/11/2020 até 20/02/2021  0.584459         0.495702      0.495702
# 10  22/12/2020 até 22/03/2021  0.578182         0.480847      0.480847
# 11  21/01/2021 até 21/04/2021  0.553525         0.473920      0.473920
# ...

# %% [markdown]
# ### Tabelas Ordenadas pelas métricas:

# %% [markdown]
# #### f1 score:

# %%
metricas_90_xg_final_f1 = metricas_90_xg_final.sort_values(by=['f1 score'], ascending=False)
metricas_90_xg_final_f1.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 9   22/11/2020 até 20/02/2021  0.584459         0.495702      0.495702
# 10  22/12/2020 até 22/03/2021  0.578182         0.480847      0.480847
# 15  21/05/2021 até 19/08/2021  0.576471         0.464455      0.464455
# 0   26/02/2020 até 26/05/2020  0.564602         0.460268      0.460268
# 8   23/10/2020 até 21/01/2021  0.556718         0.468835      0.468835
#
#     roc_auc score
# 9        0.670899
# 10       0.675053
# 15       0.653543
# 0        0.737135
# 8        0.638195

# %%
ranking_f1_90 = ranking_f1_90.append({'Modelo' : 'XGBoost', 'Período' : '22/11/2020 até 20/02/2021', 'f1 score' : 0.584459}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\1838462602.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_f1_90 = ranking_f1_90.append({'Modelo' : 'XGBoost', 'Período' : '22/11/2020 até 20/02/2021', 'f1 score' : 0.584459}, ignore_index = True)

# %% [markdown]
# #### Precision score:

# %%
metricas_90_xg_final_precision = metricas_90_xg_final.sort_values(by=['precision score'], ascending=False)
metricas_90_xg_final_precision.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 23  16/01/2022 até 16/04/2022  0.530478         0.512739      0.512739
# 9   22/11/2020 até 20/02/2021  0.584459         0.495702      0.495702
# 7   23/09/2020 até 22/12/2020  0.527950         0.481132      0.481132
# 10  22/12/2020 até 22/03/2021  0.578182         0.480847      0.480847
# 11  21/01/2021 até 21/04/2021  0.553525         0.473920      0.473920
#
#     roc_auc score
# 23       0.618302
# 9        0.670899
# 7        0.634203
# 10       0.675053
# 11       0.655338

# %%
ranking_precision_90 = ranking_precision_90.append({'Modelo' : 'XGBoost', 'Período' : '16/01/2022 até 16/04/2022', 'precision score' : 0.512739}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\292446482.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_precision_90 = ranking_precision_90.append({'Modelo' : 'XGBoost', 'Período' : '16/01/2022 até 16/04/2022', 'precision score' : 0.512739}, ignore_index = True)

# %% [markdown]
# #### Recall score:

# %%
metricas_90_xg_final_recall = metricas_90_xg_final.sort_values(by=['recall score'], ascending=False)
metricas_90_xg_final_recall.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 23  16/01/2022 até 16/04/2022  0.530478         0.512739      0.512739
# 9   22/11/2020 até 20/02/2021  0.584459         0.495702      0.495702
# 7   23/09/2020 até 22/12/2020  0.527950         0.481132      0.481132
# 10  22/12/2020 até 22/03/2021  0.578182         0.480847      0.480847
# 11  21/01/2021 até 21/04/2021  0.553525         0.473920      0.473920
#
#     roc_auc score
# 23       0.618302
# 9        0.670899
# 7        0.634203
# 10       0.675053
# 11       0.655338

# %%
ranking_recall_90 = ranking_recall_90.append({'Modelo' : 'XGBoost', 'Período' : '16/01/2022 até 16/04/2022', 'recall score' : 0.512739}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\1952956838.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_recall_90 = ranking_recall_90.append({'Modelo' : 'XGBoost', 'Período' : '16/01/2022 até 16/04/2022', 'recall score' : 0.512739}, ignore_index = True)

# %% [markdown]
# #### ROC_AUC score:

# %%
metricas_90_xg_final_roc_auc_score = metricas_90_xg_final.sort_values(by=['roc_auc score'], ascending=False)
metricas_90_xg_final_roc_auc_score.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 26/05/2020  0.564602         0.460268      0.460268
# 25  17/03/2022 até 15/06/2022  0.314286         0.201835      0.201835
# 3   26/05/2020 até 24/08/2020  0.435141         0.299905      0.299905
# 2   26/04/2020 até 25/07/2020  0.464956         0.316532      0.316532
# 1   27/03/2020 até 25/06/2020  0.532994         0.382011      0.382011
#
#     roc_auc score
# 0        0.737135
# 25       0.699482
# 3        0.682501
# 2        0.680134
# 1        0.677143

# %%
ranking_roc_auc_score_90 = ranking_roc_auc_score_90.append({'Modelo' : 'XGBoost', 'Período' : '26/02/2020 até 26/05/2020', 'roc auc score' : 0.737135}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\3449026241.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_roc_auc_score_90 = ranking_roc_auc_score_90.append({'Modelo' : 'XGBoost', 'Período' : '26/02/2020 até 26/05/2020', 'roc auc score' : 0.737135}, ignore_index = True)

# %% [markdown]
# #### 120 Dias:

# %%
metricas_120_xg = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_120_xg_final.csv")
metricas_120_xg
# Out:
#                      Períodos  accuracy score  f1 score  f1 score macro  \
# 0   26/02/2020 até 25/06/2020        0.676418  0.570949        0.655608
# 1   27/03/2020 até 25/07/2020        0.547214  0.486392        0.540774
# 2   26/04/2020 até 24/08/2020        0.597864  0.447181        0.565589
# 3   26/05/2020 até 23/09/2020        0.620336  0.456609        0.582426
# 4   25/06/2020 até 23/10/2020        0.610442  0.441459        0.571192
# 5   25/07/2020 até 22/11/2020        0.625263  0.464930        0.588296
# 6   24/08/2020 até 22/12/2020        0.638743  0.473282        0.599191
# 7   23/09/2020 até 21/01/2021        0.636026  0.558349        0.624407
# 8   23/10/2020 até 20/02/2021        0.636364  0.563776        0.626008
# 9   22/11/2020 até 22/03/2021        0.648898  0.575992        0.638201
# 10  22/12/2020 até 21/04/2021        0.624188  0.558433        0.615665
# 11  21/01/2021 até 21/05/2021        0.646034  0.551269        0.629511
# ...

# %%
metricas_120_xg_final = metricas_120_xg.drop(['accuracy score', 'f1 score macro', 'f1 score micro', 'f1 score weighted', 'precision score macro', 'precision score micro', 'precision score weighted', 'recall score macro', 'recall score micro', 'recall score weighted'], axis=1)
metricas_120_xg_final
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 25/06/2020  0.570949         0.439504      0.439504
# 1   27/03/2020 até 25/07/2020  0.486392         0.332002      0.332002
# 2   26/04/2020 até 24/08/2020  0.447181         0.305107      0.305107
# 3   26/05/2020 até 23/09/2020  0.456609         0.312900      0.312900
# 4   25/06/2020 até 23/10/2020  0.441459         0.324859      0.324859
# 5   25/07/2020 até 22/11/2020  0.464930         0.387960      0.387960
# 6   24/08/2020 até 22/12/2020  0.473282         0.449275      0.449275
# 7   23/09/2020 até 21/01/2021  0.558349         0.480044      0.480044
# 8   23/10/2020 até 20/02/2021  0.563776         0.468220      0.468220
# 9   22/11/2020 até 22/03/2021  0.575992         0.474860      0.474860
# 10  22/12/2020 até 21/04/2021  0.558433         0.455087      0.455087
# 11  21/01/2021 até 21/05/2021  0.551269         0.470986      0.470986
# ...

# %% [markdown]
# ### Tabelas Ordenadas pelas métricas:

# %% [markdown]
# #### f1 score:

# %%
metricas_120_xg_final_f1 = metricas_120_xg_final.sort_values(by=['f1 score'], ascending=False)
metricas_120_xg_final_f1.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 23  16/01/2022 até 16/05/2022  0.585885         0.505747      0.505747
# 9   22/11/2020 até 22/03/2021  0.575992         0.474860      0.474860
# 0   26/02/2020 até 25/06/2020  0.570949         0.439504      0.439504
# 8   23/10/2020 até 20/02/2021  0.563776         0.468220      0.468220
# 10  22/12/2020 até 21/04/2021  0.558433         0.455087      0.455087
#
#     roc_auc score
# 23       0.677737
# 9        0.670328
# 0        0.720676
# 8        0.654485
# 10       0.649254

# %%
ranking_f1_120 = ranking_f1_120.append({'Modelo' : 'XGBoost', 'Período' : '16/01/2022 até 16/05/2022', 'f1 score' : 0.585885}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\1710594894.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_f1_120 = ranking_f1_120.append({'Modelo' : 'XGBoost', 'Período' : '16/01/2022 até 16/05/2022', 'f1 score' : 0.585885}, ignore_index = True)

# %% [markdown]
# #### Precision score:

# %%
metricas_120_xg_final_precision = metricas_120_xg_final.sort_values(by=['precision score'], ascending=False)
metricas_120_xg_final_precision.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 23  16/01/2022 até 16/05/2022  0.585885         0.505747      0.505747
# 7   23/09/2020 até 21/01/2021  0.558349         0.480044      0.480044
# 9   22/11/2020 até 22/03/2021  0.575992         0.474860      0.474860
# 11  21/01/2021 até 21/05/2021  0.551269         0.470986      0.470986
# 8   23/10/2020 até 20/02/2021  0.563776         0.468220      0.468220
#
#     roc_auc score
# 23       0.677737
# 7        0.643404
# 9        0.670328
# 11       0.650789
# 8        0.654485

# %%
ranking_precision_120 = ranking_precision_120.append({'Modelo' : 'XGBoost', 'Período' : '16/01/2022 até 16/05/2022', 'precision score' : 0.505747}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\3940665840.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_precision_120 = ranking_precision_120.append({'Modelo' : 'XGBoost', 'Período' : '16/01/2022 até 16/05/2022', 'precision score' : 0.505747}, ignore_index = True)

# %% [markdown]
# #### Recall score:

# %%
metricas_120_xg_final_recall = metricas_120_xg_final.sort_values(by=['recall score'], ascending=False)
metricas_120_xg_final_recall.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 23  16/01/2022 até 16/05/2022  0.585885         0.505747      0.505747
# 7   23/09/2020 até 21/01/2021  0.558349         0.480044      0.480044
# 9   22/11/2020 até 22/03/2021  0.575992         0.474860      0.474860
# 11  21/01/2021 até 21/05/2021  0.551269         0.470986      0.470986
# 8   23/10/2020 até 20/02/2021  0.563776         0.468220      0.468220
#
#     roc_auc score
# 23       0.677737
# 7        0.643404
# 9        0.670328
# 11       0.650789
# 8        0.654485

# %%
ranking_recall_120 = ranking_recall_120.append({'Modelo' : 'XGBoost', 'Período' : '16/01/2022 até 16/05/2022', 'recall score' : 0.505747}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\202766659.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_recall_120 = ranking_recall_120.append({'Modelo' : 'XGBoost', 'Período' : '16/01/2022 até 16/05/2022', 'recall score' : 0.505747}, ignore_index = True)

# %% [markdown]
# #### ROC_AUC score:

# %%
metricas_120_xg_final_roc_auc_score = metricas_120_xg_final.sort_values(by=['roc_auc score'], ascending=False)
metricas_120_xg_final_roc_auc_score.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 24  15/02/2022 até 15/06/2022  0.475584         0.350000      0.350000
# 0   26/02/2020 até 25/06/2020  0.570949         0.439504      0.439504
# 3   26/05/2020 até 23/09/2020  0.456609         0.312900      0.312900
# 2   26/04/2020 até 24/08/2020  0.447181         0.305107      0.305107
# 23  16/01/2022 até 16/05/2022  0.585885         0.505747      0.505747
#
#     roc_auc score
# 24       0.726216
# 0        0.720676
# 3        0.706294
# 2        0.688542
# 23       0.677737

# %%
ranking_roc_auc_score_120 = ranking_roc_auc_score_120.append({'Modelo' : 'XGBoost', 'Período' : '15/02/2022 até 15/06/2022', 'roc auc score' : 0.726216}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\2700156657.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_roc_auc_score_120 = ranking_roc_auc_score_120.append({'Modelo' : 'XGBoost', 'Período' : '15/02/2022 até 15/06/2022', 'roc auc score' : 0.726216}, ignore_index = True)

# %% [markdown]
# ## Random Forest:

# %% [markdown]
# #### 90 Dias:

# %%
metricas_90_rf = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_90_rf_final.csv")
metricas_90_rf
# Out:
#                      Períodos  accuracy score  f1 score  f1 score macro  \
# 0   26/02/2020 até 26/05/2020        0.776868  0.503040        0.679588
# 1   27/03/2020 até 25/06/2020        0.668527  0.531816        0.637629
# 2   26/04/2020 até 25/07/2020        0.652468  0.445010        0.596020
# 3   26/05/2020 até 24/08/2020        0.716096  0.376931        0.596548
# 4   25/06/2020 até 23/09/2020        0.734343  0.339041        0.586403
# 5   25/07/2020 até 23/10/2020        0.711045  0.367171        0.589975
# 6   24/08/2020 até 22/11/2020        0.674312  0.323810        0.554654
# 7   23/09/2020 até 22/12/2020        0.668966  0.440415        0.602688
# 8   23/10/2020 até 21/01/2021        0.685109  0.542205        0.651113
# 9   22/11/2020 até 20/02/2021        0.697982  0.552577        0.662318
# 10  22/12/2020 até 22/03/2021        0.699311  0.523029        0.651741
# 11  21/01/2021 até 21/04/2021        0.686800  0.463060        0.620991
# ...

# %%
metricas_90_rf_final = metricas_90_rf.drop(['accuracy score', 'f1 score macro', 'f1 score micro', 'f1 score weighted', 'precision score macro', 'precision score micro', 'precision score weighted', 'recall score macro', 'recall score micro', 'recall score weighted'], axis=1)
metricas_90_rf_final
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 26/05/2020  0.503040         0.515844      0.515844
# 1   27/03/2020 até 25/06/2020  0.531816         0.429717      0.429717
# 2   26/04/2020 até 25/07/2020  0.445010         0.338164      0.338164
# 3   26/05/2020 até 24/08/2020  0.376931         0.320490      0.320490
# 4   25/06/2020 até 23/09/2020  0.339041         0.314286      0.314286
# 5   25/07/2020 até 23/10/2020  0.367171         0.382883      0.382883
# 6   24/08/2020 até 22/11/2020  0.323810         0.408654      0.408654
# 7   23/09/2020 até 22/12/2020  0.440415         0.505952      0.505952
# 8   23/10/2020 até 21/01/2021  0.542205         0.543825      0.543825
# 9   22/11/2020 até 20/02/2021  0.552577         0.553719      0.553719
# 10  22/12/2020 até 22/03/2021  0.523029         0.537721      0.537721
# 11  21/01/2021 até 21/04/2021  0.463060         0.521625      0.521625
# ...

# %% [markdown]
# ### Tabelas Ordenadas pelas métricas:

# %% [markdown]
# #### f1 score:

# %%
metricas_90_rf_final_f1 = metricas_90_rf_final.sort_values(by=['f1 score'], ascending=False)
metricas_90_rf_final_f1.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 9   22/11/2020 até 20/02/2021  0.552577         0.553719      0.553719
# 15  21/05/2021 até 19/08/2021  0.550436         0.531250      0.531250
# 8   23/10/2020 até 21/01/2021  0.542205         0.543825      0.543825
# 1   27/03/2020 até 25/06/2020  0.531816         0.429717      0.429717
# 10  22/12/2020 até 22/03/2021  0.523029         0.537721      0.537721
#
#     roc_auc score
# 9        0.662155
# 15       0.655356
# 8        0.650902
# 1        0.677674
# 10       0.649756

# %%
ranking_f1_90 = ranking_f1_90.append({'Modelo' : 'Random Forest', 'Período' : '22/11/2020 até 20/02/2021', 'f1 score' : 0.552577}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\3206503065.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_f1_90 = ranking_f1_90.append({'Modelo' : 'Random Forest', 'Período' : '22/11/2020 até 20/02/2021', 'f1 score' : 0.552577}, ignore_index = True)

# %% [markdown]
# #### Precision score:

# %%
metricas_90_rf_final_precision = metricas_90_rf_final.sort_values(by=['precision score'], ascending=False)
metricas_90_rf_final_precision.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 23  16/01/2022 até 16/04/2022  0.428875         0.567416      0.567416
# 9   22/11/2020 até 20/02/2021  0.552577         0.553719      0.553719
# 8   23/10/2020 até 21/01/2021  0.542205         0.543825      0.543825
# 10  22/12/2020 até 22/03/2021  0.523029         0.537721      0.537721
# 15  21/05/2021 até 19/08/2021  0.550436         0.531250      0.531250
#
#     roc_auc score
# 23       0.593623
# 9        0.662155
# 8        0.650902
# 10       0.649756
# 15       0.655356

# %%
ranking_precision_90 = ranking_precision_90.append({'Modelo' : 'Random Forest', 'Período' : '16/01/2022 até 16/04/2022', 'precision score' : 0.567416}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\1121041864.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_precision_90 = ranking_precision_90.append({'Modelo' : 'Random Forest', 'Período' : '16/01/2022 até 16/04/2022', 'precision score' : 0.567416}, ignore_index = True)

# %% [markdown]
# #### Recall score:

# %%
metricas_90_rf_final_recall = metricas_90_rf_final.sort_values(by=['recall score'], ascending=False)
metricas_90_rf_final_recall.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 23  16/01/2022 até 16/04/2022  0.428875         0.567416      0.567416
# 9   22/11/2020 até 20/02/2021  0.552577         0.553719      0.553719
# 8   23/10/2020 até 21/01/2021  0.542205         0.543825      0.543825
# 10  22/12/2020 até 22/03/2021  0.523029         0.537721      0.537721
# 15  21/05/2021 até 19/08/2021  0.550436         0.531250      0.531250
#
#     roc_auc score
# 23       0.593623
# 9        0.662155
# 8        0.650902
# 10       0.649756
# 15       0.655356

# %%
ranking_recall_90 = ranking_recall_90.append({'Modelo' : 'Random Forest', 'Período' : '16/01/2022 até 16/04/2022', 'recall score' : 0.567416}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\369015991.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_recall_90 = ranking_recall_90.append({'Modelo' : 'Random Forest', 'Período' : '16/01/2022 até 16/04/2022', 'recall score' : 0.567416}, ignore_index = True)

# %% [markdown]
# #### ROC_AUC score:

# %%
metricas_90_rf_final_roc_auc_score = metricas_90_rf_final.sort_values(by=['roc_auc score'], ascending=False)
metricas_90_rf_final_roc_auc_score.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 25  17/03/2022 até 15/06/2022  0.360360         0.250000      0.250000
# 1   27/03/2020 até 25/06/2020  0.531816         0.429717      0.429717
# 0   26/02/2020 até 26/05/2020  0.503040         0.515844      0.515844
# 9   22/11/2020 até 20/02/2021  0.552577         0.553719      0.553719
# 24  15/02/2022 até 16/05/2022  0.515152         0.490385      0.490385
#
#     roc_auc score
# 25       0.715438
# 1        0.677674
# 0        0.676594
# 9        0.662155
# 24       0.658029

# %%
ranking_roc_auc_score_90 = ranking_roc_auc_score_90.append({'Modelo' : 'Random Forest', 'Período' : '17/03/2022 até 15/06/2022', 'roc auc score' : 0.715438}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\1011730061.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_roc_auc_score_90 = ranking_roc_auc_score_90.append({'Modelo' : 'Random Forest', 'Período' : '17/03/2022 até 15/06/2022', 'roc auc score' : 0.715438}, ignore_index = True)

# %% [markdown]
# #### 120 Dias:

# %%
metricas_120_rf = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_120_rf_final.csv")
metricas_120_rf
# Out:
#                      Períodos  accuracy score  f1 score  f1 score macro  \
# 0   26/02/2020 até 25/06/2020        0.714159  0.547967        0.669483
# 1   27/03/2020 até 25/07/2020        0.644737  0.489433        0.608515
# 2   26/04/2020 até 24/08/2020        0.659201  0.421299        0.589892
# 3   26/05/2020 até 23/09/2020        0.724347  0.402427        0.611641
# 4   25/06/2020 até 23/10/2020        0.700803  0.374825        0.589084
# 5   25/07/2020 até 22/11/2020        0.690526  0.369099        0.582039
# 6   24/08/2020 até 22/12/2020        0.660268  0.337868        0.554693
# 7   23/09/2020 até 21/01/2021        0.670563  0.495114        0.625317
# 8   23/10/2020 até 20/02/2021        0.675704  0.530046        0.641241
# 9   22/11/2020 até 22/03/2021        0.698196  0.516998        0.648764
# 10  22/12/2020 até 21/04/2021        0.687482  0.473333        0.625578
# 11  21/01/2021 até 21/05/2021        0.686606  0.482166        0.628739
# ...

# %%
metricas_120_rf_final = metricas_120_rf.drop(['accuracy score', 'f1 score macro', 'f1 score micro', 'f1 score weighted', 'precision score macro', 'precision score micro', 'precision score weighted', 'recall score macro', 'recall score micro', 'recall score weighted'], axis=1)
metricas_120_rf_final
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 25/06/2020  0.547967         0.470750      0.470750
# 1   27/03/2020 até 25/07/2020  0.489433         0.370163      0.370163
# 2   26/04/2020 até 24/08/2020  0.421299         0.314410      0.314410
# 3   26/05/2020 até 23/09/2020  0.402427         0.340753      0.340753
# 4   25/06/2020 até 23/10/2020  0.374825         0.351706      0.351706
# 5   25/07/2020 até 22/11/2020  0.369099         0.431438      0.431438
# 6   24/08/2020 até 22/12/2020  0.337868         0.459877      0.459877
# 7   23/09/2020 até 21/01/2021  0.495114         0.525043      0.525043
# 8   23/10/2020 até 20/02/2021  0.530046         0.510386      0.510386
# 9   22/11/2020 até 22/03/2021  0.516998         0.540214      0.540214
# 10  22/12/2020 até 21/04/2021  0.473333         0.530983      0.530983
# 11  21/01/2021 até 21/05/2021  0.482166         0.524790      0.524790
# ...

# %% [markdown]
# ### Tabelas Ordenadas pelas métricas:

# %% [markdown]
# #### f1 score:

# %%
metricas_120_rf_final_f1 = metricas_120_rf_final.sort_values(by=['f1 score'], ascending=False)
metricas_120_rf_final_f1.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 25/06/2020  0.547967         0.470750      0.470750
# 14  21/04/2021 até 19/08/2021  0.532986         0.507438      0.507438
# 8   23/10/2020 até 20/02/2021  0.530046         0.510386      0.510386
# 15  21/05/2021 até 18/09/2021  0.529338         0.490741      0.490741
# 9   22/11/2020 até 22/03/2021  0.516998         0.540214      0.540214
#
#     roc_auc score
# 0        0.695362
# 14       0.656040
# 8        0.644376
# 15       0.644591
# 9        0.645886

# %% [markdown]
# #### Precision score:

# %%
metricas_120_rf_final_precision = metricas_120_rf_final.sort_values(by=['precision score'], ascending=False)
metricas_120_rf_final_precision.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 23  16/01/2022 até 16/05/2022  0.435606         0.542453      0.542453
# 9   22/11/2020 até 22/03/2021  0.516998         0.540214      0.540214
# 10  22/12/2020 até 21/04/2021  0.473333         0.530983      0.530983
# 7   23/09/2020 até 21/01/2021  0.495114         0.525043      0.525043
# 11  21/01/2021 até 21/05/2021  0.482166         0.524790      0.524790
#
#     roc_auc score
# 23       0.605100
# 9        0.645886
# 10       0.621067
# 7        0.622690
# 11       0.624790

# %% [markdown]
# #### Recall score:

# %%
metricas_120_rf_final_recall = metricas_120_rf_final.sort_values(by=['recall score'], ascending=False)
metricas_120_rf_final_recall.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 23  16/01/2022 até 16/05/2022  0.435606         0.542453      0.542453
# 9   22/11/2020 até 22/03/2021  0.516998         0.540214      0.540214
# 10  22/12/2020 até 21/04/2021  0.473333         0.530983      0.530983
# 7   23/09/2020 até 21/01/2021  0.495114         0.525043      0.525043
# 11  21/01/2021 até 21/05/2021  0.482166         0.524790      0.524790
#
#     roc_auc score
# 23       0.605100
# 9        0.645886
# 10       0.621067
# 7        0.622690
# 11       0.624790

# %% [markdown]
# #### ROC_AUC score:

# %%
metricas_120_rf_final_roc_auc_score = metricas_120_rf_final.sort_values(by=['roc_auc score'], ascending=False)
metricas_120_rf_final_roc_auc_score.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 25/06/2020  0.547967         0.470750      0.470750
# 1   27/03/2020 até 25/07/2020  0.489433         0.370163      0.370163
# 24  15/02/2022 até 15/06/2022  0.437500         0.383085      0.383085
# 14  21/04/2021 até 19/08/2021  0.532986         0.507438      0.507438
# 2   26/04/2020 até 24/08/2020  0.421299         0.314410      0.314410
#
#     roc_auc score
# 0        0.695362
# 1        0.671482
# 24       0.668736
# 14       0.656040
# 2        0.651270

# %% [markdown]
# #### Adição de todas as métricas:

# %%
ranking_f1_120 = ranking_f1_120.append({'Modelo' : 'Random Forest', 'Período' : '26/02/2020 até 25/06/2020', 'f1 score' : 0.547967}, ignore_index = True)
ranking_precision_120 = ranking_precision_120.append({'Modelo' : 'Random Forest', 'Período' : '16/01/2022 até 16/05/2022', 'precision score' : 0.542453}, ignore_index = True)
ranking_precision_120 = ranking_recall_120.append({'Modelo' : 'Random Forest', 'Período' : '16/01/2022 até 16/05/2022', 'recall score' : 0.542453}, ignore_index = True)
ranking_roc_auc_score_120 = ranking_roc_auc_score_120.append({'Modelo' : 'Random Forest', 'Período' : '26/02/2020 até 25/06/2020', 'roc auc score' : 0.695362}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\2661016013.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_f1_120 = ranking_f1_120.append({'Modelo' : 'Random Forest', 'Período' : '26/02/2020 até 25/06/2020', 'f1 score' : 0.547967}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\2661016013.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_precision_120 = ranking_precision_120.append({'Modelo' : 'Random Forest', 'Período' : '16/01/2022 até 16/05/2022', 'precision score' : 0.542453}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\2661016013.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# ## SVM:

# %% [markdown]
# #### 90 Dias:

# %%
metricas_90_svm = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_90_svm_final.csv")
metricas_90_svm
# Out:
#                      Períodos  accuracy score  f1 score  f1 score macro  \
# 0   26/02/2020 até 26/05/2020        0.746275  0.595467        0.705322
# 1   27/03/2020 até 25/06/2020        0.648894  0.566913        0.635846
# 2   26/04/2020 até 25/07/2020        0.648089  0.475682        0.605426
# 3   26/05/2020 até 24/08/2020        0.690286  0.412811        0.601243
# 4   25/06/2020 até 23/09/2020        0.690984  0.357654        0.577105
# 5   25/07/2020 até 23/10/2020        0.632150  0.412598        0.572416
# 6   24/08/2020 até 22/11/2020        0.646789  0.389857        0.570655
# 7   23/09/2020 até 22/12/2020        0.661303  0.467470        0.609578
# 8   23/10/2020 até 21/01/2021        0.682377  0.584450        0.663701
# 9   22/11/2020 até 20/02/2021        0.675713  0.556190        0.650354
# 10  22/12/2020 até 22/03/2021        0.702264  0.548170        0.663076
# 11  21/01/2021 até 21/04/2021        0.669834  0.459144        0.610769
# ...

# %%
metricas_90_svm_final = metricas_90_svm.drop(['accuracy score', 'f1 score macro', 'f1 score micro', 'f1 score weighted', 'precision score macro', 'precision score micro', 'precision score weighted', 'recall score macro', 'recall score micro', 'recall score weighted'], axis=1)
metricas_90_svm_final
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 26/05/2020  0.595467         0.470218      0.470218
# 1   27/03/2020 até 25/06/2020  0.566913         0.424914      0.424914
# 2   26/04/2020 até 25/07/2020  0.475682         0.349303      0.349303
# 3   26/05/2020 até 24/08/2020  0.412811         0.320442      0.320442
# 4   25/06/2020 até 23/09/2020  0.357654         0.290698      0.290698
# 5   25/07/2020 até 23/10/2020  0.412598         0.332487      0.332487
# 6   24/08/2020 até 22/11/2020  0.389857         0.391720      0.391720
# 7   23/09/2020 até 22/12/2020  0.467470         0.492386      0.492386
# 8   23/10/2020 até 21/01/2021  0.584450         0.532573      0.532573
# 9   22/11/2020 até 20/02/2021  0.556190         0.517730      0.517730
# 10  22/12/2020 até 22/03/2021  0.548170         0.538913      0.538913
# 11  21/01/2021 até 21/04/2021  0.459144         0.489917      0.489917
# ...

# %% [markdown]
# ### Tabelas Ordenadas pelas métricas:

# %% [markdown]
# #### f1 score:

# %%
metricas_90_svm_final_f1 = metricas_90_svm_final.sort_values(by=['f1 score'], ascending=False)
metricas_90_svm_final_f1.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 26/05/2020  0.595467         0.470218      0.470218
# 8   23/10/2020 até 21/01/2021  0.584450         0.532573      0.532573
# 1   27/03/2020 até 25/06/2020  0.566913         0.424914      0.424914
# 9   22/11/2020 até 20/02/2021  0.556190         0.517730      0.517730
# 12  20/02/2021 até 21/05/2021  0.548876         0.513196      0.513196
#
#     roc_auc score
# 0        0.769201
# 8        0.674127
# 1        0.712736
# 9        0.657404
# 12       0.664098

# %% [markdown]
# #### Precision score:

# %%
metricas_90_svm_final_precision = metricas_90_svm_final.sort_values(by=['precision score'], ascending=False)
metricas_90_svm_final_precision.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 10  22/12/2020 até 22/03/2021  0.548170         0.538913      0.538913
# 23  16/01/2022 até 16/04/2022  0.395699         0.534884      0.534884
# 8   23/10/2020 até 21/01/2021  0.584450         0.532573      0.532573
# 15  21/05/2021 até 19/08/2021  0.528883         0.525510      0.525510
# 9   22/11/2020 até 20/02/2021  0.556190         0.517730      0.517730
#
#     roc_auc score
# 10       0.664610
# 23       0.575197
# 8        0.674127
# 15       0.641984
# 9        0.657404

# %% [markdown]
# #### Recall score:

# %%
metricas_90_svm_final_recall = metricas_90_svm_final.sort_values(by=['recall score'], ascending=False)
metricas_90_svm_final_recall.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 10  22/12/2020 até 22/03/2021  0.548170         0.538913      0.538913
# 23  16/01/2022 até 16/04/2022  0.395699         0.534884      0.534884
# 8   23/10/2020 até 21/01/2021  0.584450         0.532573      0.532573
# 15  21/05/2021 até 19/08/2021  0.528883         0.525510      0.525510
# 9   22/11/2020 até 20/02/2021  0.556190         0.517730      0.517730
#
#     roc_auc score
# 10       0.664610
# 23       0.575197
# 8        0.674127
# 15       0.641984
# 9        0.657404

# %% [markdown]
# #### ROC_AUC score:

# %%
metricas_90_svm_final_roc_auc_score = metricas_90_svm_final.sort_values(by=['roc_auc score'], ascending=False)
metricas_90_svm_final_roc_auc_score.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 26/05/2020  0.595467         0.470218      0.470218
# 1   27/03/2020 até 25/06/2020  0.566913         0.424914      0.424914
# 25  17/03/2022 até 15/06/2022  0.322034         0.218391      0.218391
# 2   26/04/2020 até 25/07/2020  0.475682         0.349303      0.349303
# 8   23/10/2020 até 21/01/2021  0.584450         0.532573      0.532573
#
#     roc_auc score
# 0        0.769201
# 1        0.712736
# 25       0.685023
# 2        0.683467
# 8        0.674127

# %%
ranking_f1_90 = ranking_f1_90.append({'Modelo' : 'SVM', 'Período' : '26/02/2020 até 26/05/2020', 'f1 score' : 0.595467}, ignore_index = True)
ranking_precision_90 = ranking_precision_90.append({'Modelo' : 'SVM', 'Período' : '	22/12/2020 até 22/03/2021', 'precision score' : 0.538913}, ignore_index = True)
ranking_precision_90 = ranking_recall_90.append({'Modelo' : 'SVM', 'Período' : '22/12/2020 até 22/03/2021', 'recall score' : 0.538913}, ignore_index = True)
ranking_roc_auc_score_90 = ranking_roc_auc_score_90.append({'Modelo' : 'SVM', 'Período' : '26/02/2020 até 26/05/2020', 'roc auc score' : 0.769201}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\586480226.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_f1_90 = ranking_f1_90.append({'Modelo' : 'SVM', 'Período' : '26/02/2020 até 26/05/2020', 'f1 score' : 0.595467}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\586480226.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_precision_90 = ranking_precision_90.append({'Modelo' : 'SVM', 'Período' : '	22/12/2020 até 22/03/2021', 'precision score' : 0.538913}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\586480226.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# #### 120 Dias:

# %%
metricas_120_svm = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_120_svm_final.csv")
metricas_120_svm
# Out:
#                      Períodos  accuracy score  f1 score  f1 score macro  \
# 0   26/02/2020 até 25/06/2020        0.684144  0.587359        0.665756
# 1   27/03/2020 até 25/07/2020        0.631063  0.516238        0.609037
# 2   26/04/2020 até 24/08/2020        0.659890  0.451362        0.602460
# 3   26/05/2020 até 23/09/2020        0.683769  0.410435        0.597187
# 4   25/06/2020 até 23/10/2020        0.627845  0.438384        0.580053
# 5   25/07/2020 até 22/11/2020        0.630175  0.451613        0.586315
# 6   24/08/2020 até 22/12/2020        0.645143  0.445455        0.592274
# 7   23/09/2020 até 21/01/2021        0.689160  0.528606        0.648370
# 8   23/10/2020 até 20/02/2021        0.666135  0.550143        0.642358
# 9   22/11/2020 até 22/03/2021        0.687375  0.531813        0.648578
# 10  22/12/2020 até 21/04/2021        0.698220  0.534843        0.655753
# 11  21/01/2021 até 21/05/2021        0.667620  0.484677        0.619690
# ...

# %%
metricas_120_svm_final = metricas_120_svm.drop(['accuracy score', 'f1 score macro', 'f1 score micro', 'f1 score weighted', 'precision score macro', 'precision score micro', 'precision score weighted', 'recall score macro', 'recall score micro', 'recall score weighted'], axis=1)
metricas_120_svm_final
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 25/06/2020  0.587359         0.448572      0.448572
# 1   27/03/2020 até 25/07/2020  0.516238         0.373653      0.373653
# 2   26/04/2020 até 24/08/2020  0.451362         0.328745      0.328745
# 3   26/05/2020 até 23/09/2020  0.410435         0.316779      0.316779
# 4   25/06/2020 até 23/10/2020  0.438384         0.330793      0.330793
# 5   25/07/2020 até 22/11/2020  0.451613         0.386809      0.386809
# 6   24/08/2020 até 22/12/2020  0.445455         0.452030      0.452030
# 7   23/09/2020 até 21/01/2021  0.528606         0.554054      0.554054
# 8   23/10/2020 até 20/02/2021  0.550143         0.497409      0.497409
# 9   22/11/2020 até 22/03/2021  0.531813         0.519343      0.519343
# 10  22/12/2020 até 21/04/2021  0.534843         0.542403      0.542403
# 11  21/01/2021 até 21/05/2021  0.484677         0.491817      0.491817
# ...

# %% [markdown]
# ### Tabelas Ordenadas pelas métricas:

# %% [markdown]
# #### f1 score:

# %%
metricas_120_svm_final_f1 = metricas_120_svm_final.sort_values(by=['f1 score'], ascending=False)
metricas_120_svm_final_f1.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 25/06/2020  0.587359         0.448572      0.448572
# 15  21/05/2021 até 18/09/2021  0.561905         0.501062      0.501062
# 12  20/02/2021 até 20/06/2021  0.553444         0.489496      0.489496
# 8   23/10/2020 até 20/02/2021  0.550143         0.497409      0.497409
# 14  21/04/2021 até 19/08/2021  0.545455         0.518092      0.518092
#
#     roc_auc score
# 0        0.737440
# 15       0.667384
# 12       0.671979
# 8        0.653357
# 14       0.665443

# %% [markdown]
# #### Precision score:

# %%
metricas_120_svm_final_precision = metricas_120_svm_final.sort_values(by=['precision score'], ascending=False)
metricas_120_svm_final_precision.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 7   23/09/2020 até 21/01/2021  0.528606         0.554054      0.554054
# 10  22/12/2020 até 21/04/2021  0.534843         0.542403      0.542403
# 9   22/11/2020 até 22/03/2021  0.531813         0.519343      0.519343
# 14  21/04/2021 até 19/08/2021  0.545455         0.518092      0.518092
# 23  16/01/2022 até 16/05/2022  0.461806         0.511538      0.511538
#
#     roc_auc score
# 7        0.645640
# 10       0.654693
# 9        0.650569
# 14       0.665443
# 23       0.609809

# %% [markdown]
# #### Recall score:

# %%
metricas_120_svm_final_recall = metricas_120_svm_final.sort_values(by=['recall score'], ascending=False)
metricas_120_svm_final_recall.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 7   23/09/2020 até 21/01/2021  0.528606         0.554054      0.554054
# 10  22/12/2020 até 21/04/2021  0.534843         0.542403      0.542403
# 9   22/11/2020 até 22/03/2021  0.531813         0.519343      0.519343
# 14  21/04/2021 até 19/08/2021  0.545455         0.518092      0.518092
# 23  16/01/2022 até 16/05/2022  0.461806         0.511538      0.511538
#
#     roc_auc score
# 7        0.645640
# 10       0.654693
# 9        0.650569
# 14       0.665443
# 23       0.609809

# %% [markdown]
# #### ROC_AUC score:

# %%
metricas_120_svm_final_roc_auc_score = metricas_120_svm_final.sort_values(by=['roc_auc score'], ascending=False)
metricas_120_svm_final_roc_auc_score.head(5)
# Out:
#                      Períodos  f1 score  precision score  recall score  \
# 0   26/02/2020 até 25/06/2020  0.587359         0.448572      0.448572
# 1   27/03/2020 até 25/07/2020  0.516238         0.373653      0.373653
# 24  15/02/2022 até 15/06/2022  0.457143         0.376068      0.376068
# 2   26/04/2020 até 24/08/2020  0.451362         0.328745      0.328745
# 12  20/02/2021 até 20/06/2021  0.553444         0.489496      0.489496
#
#     roc_auc score
# 0        0.737440
# 1        0.701495
# 24       0.689861
# 2        0.682641
# 12       0.671979

# %%
ranking_f1_120 = ranking_f1_120.append({'Modelo' : 'SVM', 'Período' : '26/02/2020 até 25/06/2020', 'f1 score' : 0.587359}, ignore_index = True)
ranking_precision_120 = ranking_precision_120.append({'Modelo' : 'SVM', 'Período' : '23/09/2020 até 21/01/2021', 'precision score' : 0.554054}, ignore_index = True)
ranking_precision_120 = ranking_recall_120.append({'Modelo' : 'SVM', 'Período' : '23/09/2020 até 21/01/2021', 'recall score' : 0.554054}, ignore_index = True)
ranking_roc_auc_score_120 = ranking_roc_auc_score_120.append({'Modelo' : 'SVM', 'Período' : '26/02/2020 até 25/06/2020', 'roc auc score' : 0.737440}, ignore_index = True)
# Out:
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\2796976339.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_f1_120 = ranking_f1_120.append({'Modelo' : 'SVM', 'Período' : '26/02/2020 até 25/06/2020', 'f1 score' : 0.587359}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\2796976339.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ranking_precision_120 = ranking_precision_120.append({'Modelo' : 'SVM', 'Período' : '23/09/2020 até 21/01/2021', 'precision score' : 0.554054}, ignore_index = True)
# C:\Users\maril\AppData\Local\Temp\ipykernel_17944\2796976339.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# ## KNN:

# %% [markdown]
# #### 90 Dias:

# %%
metricas_90_knn = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_90_knn_final.csv")
metricas_90_knn

# %% [markdown]
# #### 120 Dias:

# %%
metricas_120_knn = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_120_knn_final.csv")
metricas_120_knn

# %% [markdown]
# ## Gradient Boosting:

# %% [markdown]
# #### 90 Dias:

# %% [markdown]
# #### 120 Dias:

# %%
metricas_120_gb = pd.read_csv(r"C:\Users\maril\OneDrive\Área de Trabalho\Estudo_dados_de_covid\Codes\Classificação\metricas_120_knn_final.csv")
metricas_120_gb
